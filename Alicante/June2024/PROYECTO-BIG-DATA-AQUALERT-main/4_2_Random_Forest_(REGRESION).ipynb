# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import drive
drive.mount('/content/drive/')

# Cargar el archivo CSV en un DataFrame de pandas
input_path_train = '/content/drive/My Drive/0. JOSE IES SV/Entrenamiento_hasta_2017_LU(PRE_RANDOM_FOREST).csv'
df_train_csv_LU = pd.read_csv(input_path_train)

input_path_test= '/content/drive/My Drive/0. JOSE IES SV/Test_2018_LU(PRE_RANDOM_FOREST).csv'
df_test_csv_LU = pd.read_csv(input_path_test)
# Out:
# Mounted at /content/drive/

# %%
# Análisis de posibles variables categóricas convertirlas a variables dummy

# Dimensiones: serán las dummys
# * monitoringSiteIdentifier  --> lugar de la recogida de la muestra
# * parameterWaterBodyCategory  --> tipo de medio en el lugar (río, lago, etc) donde se tomó la muestra
# * observedPropertyDeterminandCode --> que tipo de compuesto se analiza en la muestra
# * resultUom --> unidad de medida de la muestra
# * procedureAnalyticalMethod --> Qué tipo de procedimiento analítico se ha realizado en la toma de la muestra

# Dimensión Fecha:
# * phenomenonTimeSamplingDate --> fecha

# Campos numéricos:
# * procedureLOQValue -->  toma mínima que tiene que tener la muestra
# * parameterSampleDepth  --> profundidad de la toma de la muestra
# * resultQualityObservedValueBelowLOQ  --> true o false,  por si algún día queremos hacer clasificaciones, pero aquí no
#                                       --> Indicador para señalar si el valor de la muestra estaba por debajo del límite de
#                                       --> cuantificación analítica (LOQ). 0: false*1: true

# Resultados campo numérico:
# * resultObservedValue --> cantidad de compuesto analizado que hay en la muestra, le vamos a hacer una predicción

# %%
# Dimensiones: serán las dummys
# * monitoringSiteIdentifier  --> lugar de la recogida de la muestra (EN LUXEMBURGO)
# * parameterWaterBodyCategory  --> tipo de medio en el lugar (río, lago, etc) donde se tomó la muestra
# * observedPropertyDeterminandCode --> que tipo de compuesto se analiza en la muestra
# * resultUom --> unidad de medida de la muestra
# * procedureAnalyticalMethod --> Qué tipo de procedimiento analítico se ha realizado en la toma de la muestra

required_columns = ['monitoringSiteIdentifier','parameterWaterBodyCategory','observedPropertyDeterminandCode',
                    'resultUom','procedureAnalyticalMethod']

# Verificar las columnas antes de llamar a pd.get_dummies()

for col in required_columns:
    if col not in df_train_csv_LU.columns:
        raise KeyError(f"La columna '{col}' no existe en el DataFrame df_train_csv_LU. Verifica los nombres de las columnas train.")

for col in required_columns:
    if col not in df_test_csv_LU.columns:
        raise KeyError(f"La columna '{col}' no existe en el DataFrame df_test_csv_LU. Verifica los nombres de las columnas test.")

# %%
# Preparamos lasvariables categóricas en variables dummy usando el sistema binario (0 o 1), y permitiendo al multicolinealidad

df_train_csv_LU = pd.get_dummies(df_train_csv_LU, columns=required_columns, drop_first=True)
df_train_csv_LU.head()
df_test_csv_LU = pd.get_dummies(df_test_csv_LU, columns=required_columns, drop_first=True)
df_test_csv_LU.head()
# Out:
#   phenomenonTimeSamplingDate  resultObservedValue  \
# 0                 2018-01-08                 3.00
# 1                 2018-01-08                 3.00
# 2                 2018-01-08                 0.05
# 3                 2018-01-08                 0.05
# 4                 2018-01-08                 0.05
#
#    resultQualityObservedValueBelowLOQ  procedureLOQValue  \
# 0                                   1               3.00
# 1                                   1               3.00
# 2                                   1               0.05
# 3                                   1               0.05
# 4                                   1               0.05
#
#    parameterSampleDepth  monitoringSiteIdentifier_LUL112010A11  \
# 0                   0.0                                  False
# 1                   0.0                                   True
# 2                   0.0                                  False
# 3                   0.0                                   True
# 4                   0.0                                  False
#
#    observedPropertyDeterminandCode_CAS_111988-49-9  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
#
#    observedPropertyDeterminandCode_CAS_114-07-8  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    observedPropertyDeterminandCode_CAS_128-37-0  \
# 0                                          True
# 1                                          True
# 2                                         False
# 3                                         False
# 4                                         False
#
#    observedPropertyDeterminandCode_CAS_135410-20-7  ...  \
# 0                                            False  ...
# 1                                            False  ...
# 2                                            False  ...
# 3                                            False  ...
# 4                                            False  ...
#
#    observedPropertyDeterminandCode_CAS_2032-65-7  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    observedPropertyDeterminandCode_CAS_210880-92-5  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
#
#    observedPropertyDeterminandCode_CAS_2303-17-5  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    observedPropertyDeterminandCode_CAS_50-28-2  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    observedPropertyDeterminandCode_CAS_53-16-7  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    observedPropertyDeterminandCode_CAS_5466-77-3  \
# 0                                          False
# 1                                          False
# 2                                           True
# 3                                           True
# 4                                          False
#
#    observedPropertyDeterminandCode_CAS_57-63-6  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    observedPropertyDeterminandCode_CAS_81103-11-9  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    observedPropertyDeterminandCode_CAS_83905-01-5  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                            True
#
#    procedureAnalyticalMethod_Other analytical method
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
# [5 rows x 23 columns]

# %%
# Asegurarse de que los conjuntos de datos tengan las mismas columnas
df_test_csv_LU = df_test_csv_LU.reindex(columns=df_train_csv_LU.columns, fill_value=0)

# Separar las características (X) y la variable objetivo (y) para ambos conjuntos
X_train = df_train_csv_LU.drop(['resultObservedValue', 'phenomenonTimeSamplingDate'], axis=1)
y_train = df_train_csv_LU['resultObservedValue']
X_test = df_test_csv_LU.drop(['resultObservedValue', 'phenomenonTimeSamplingDate'], axis=1)
y_test = df_test_csv_LU['resultObservedValue']

# %%
# Crear y entrenar el modelo de Random Forest
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
import joblib
from sklearn.ensemble import RandomForestRegressor

joblib.dump(model, '/content/drive/My Drive/0. JOSE IES SV/ModeloRandomForestRegresion.joblib')
# Out:
# ['/content/drive/My Drive/0. JOSE IES SV/ModeloRandomForestRegresion.joblib']

# %%
# Hacer predicciones en el conjunto de prueba
y_pred = model.predict(X_test)

# %%
# Calcular métricas de evaluación
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Error Cuadrático Medio (MSE): {mse:.2f}')
print(f'Error Absoluto Medio (MAE): {mae:.2f}')
print(f'Coeficiente de Determinación (R2): {r2:.2f}')
# Out:
# Error Cuadrático Medio (MSE): 0.00
# Error Absoluto Medio (MAE): 0.01
# Coeficiente de Determinación (R2): 1.00

# %%
# Mostrar las predicciones y los valores reales
resultados = pd.DataFrame({'Real': y_test, 'Predicción': y_pred})
print(resultados)
# Out:
#     Real  Predicción
# 0   3.00        3.00
# 1   3.00        3.00
# 2   0.05        0.05
# 3   0.05        0.05
# 4   0.05        0.05
# ..   ...         ...
# 63  0.02        0.02
# 64  0.02        0.02
# 65  0.02        0.02
# 66  0.05        0.05
# 67  0.05        0.05
#
# [68 rows x 2 columns]

# %%
# Visualización de Predicciones vs Valores Reales
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, color='blue', edgecolor='k')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Valor Real')
plt.ylabel('Predicción')
plt.title('Predicción vs Valor Real')
plt.show()

# %%
# Evaluación con Validación Cruzada
cv_scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', cv=5)
mse_cv = -cv_scores.mean()
print(f'MSE de Validación Cruzada: {mse_cv:.2f}')
# Out:
# MSE de Validación Cruzada: 0.00

# %%
# Ajuste de Hiperparámetros
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10]
}

# %%
grid_search = GridSearchCV(RandomForestRegressor(random_state=42), param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)

best_model = grid_search.best_estimator_
print(f'Mejor modelo: {best_model}')
# Out:
# Mejor modelo: RandomForestRegressor(min_samples_split=10, random_state=42)

# %%
# Importancia de las Características
importances = best_model.feature_importances_
feature_names = X_train.columns
importance_df = pd.DataFrame({'Características': feature_names, 'Importancia': importances})
importance_df = importance_df.sort_values(by='Importancia', ascending=False)
print(importance_df)
# Out:
#                                       Características  Importancia
# 1                                   procedureLOQValue     0.509273
# 6        observedPropertyDeterminandCode_CAS_128-37-0     0.488688
# 0                  resultQualityObservedValueBelowLOQ     0.001590
# 21  procedureAnalyticalMethod_Other analytical method     0.000285
# 3               monitoringSiteIdentifier_LUL112010A11     0.000128
# 9      observedPropertyDeterminandCode_CAS_15307-86-5     0.000024
# 12      observedPropertyDeterminandCode_CAS_2032-65-7     0.000006
# 5        observedPropertyDeterminandCode_CAS_114-07-8     0.000006
# 20     observedPropertyDeterminandCode_CAS_83905-01-5     0.000001
# 2                                parameterSampleDepth     0.000000
# 4     observedPropertyDeterminandCode_CAS_111988-49-9     0.000000
# 10    observedPropertyDeterminandCode_CAS_153719-23-4     0.000000
# 8     observedPropertyDeterminandCode_CAS_138261-41-3     0.000000
# 7     observedPropertyDeterminandCode_CAS_135410-20-7     0.000000
# 13    observedPropertyDeterminandCode_CAS_210880-92-5     0.000000
# 11     observedPropertyDeterminandCode_CAS_19666-30-9     0.000000
# 14      observedPropertyDeterminandCode_CAS_2303-17-5     0.000000
# 15        observedPropertyDeterminandCode_CAS_50-28-2     0.000000
# 17      observedPropertyDeterminandCode_CAS_5466-77-3     0.000000
# 16        observedPropertyDeterminandCode_CAS_53-16-7     0.000000
# 19     observedPropertyDeterminandCode_CAS_81103-11-9     0.000000
# 18        observedPropertyDeterminandCode_CAS_57-63-6     0.000000

# %%
# Visualización de Importancia de las Características
plt.figure(figsize=(12, 6))
sns.barplot(x='Importancia', y='Características', data=importance_df)
plt.title('Importancia de las Características')
plt.show()
