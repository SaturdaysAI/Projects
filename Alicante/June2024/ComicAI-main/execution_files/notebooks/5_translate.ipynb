# %%
import os
from deep_translator import GoogleTranslator

# %%
# Función para traducir texto usando GoogleTranslator
def traducir_texto(texto):
    if texto.strip().lower() == "nan":
        return ""
    try:
        return GoogleTranslator(source='en', target='es').translate(texto)
    except Exception as e:
        print(f'Error en la traducción: {e}')
        return ""

# Función para procesar archivos en un directorio y sus subdirectorios
def procesar_directorio(input_dir, output_dir):
    for root, dirs, files in os.walk(input_dir):
        for file in files:
            if file.endswith(".txt"):
                input_path = os.path.join(root, file)
                relative_path = os.path.relpath(input_path, input_dir)
                output_path = os.path.join(output_dir, relative_path)

                # Crear directorio de salida si no existe
                os.makedirs(os.path.dirname(output_path), exist_ok=True)

                # Leer contenido del archivo
                with open(input_path, 'r', encoding='utf-8') as f:
                    contenido = f.read()

                # Traducir contenido
                traduccion = traducir_texto(contenido)

                # Imprimir texto original y traducción
                print(f'Texto original: {contenido}')
                print(f'Traducción: {traduccion}')

                # Guardar traducción en archivo de salida
                with open(output_path, 'w', encoding='utf-8') as f:
                    f.write(traduccion)

# Ruta del directorio de entrada y salida
input_dir = r"..\..\data\output\output_description_test"
output_dir = r"..\..\data\output\output_description_translate_test"

# Procesar el directorio
procesar_directorio(input_dir, output_dir)
# Out:
# Texto original: a person is looking at a house in a forest
# Traducción: Una persona está mirando una casa en un bosque.
# Texto original: edrei's face looks upset and sad
# Traducción: La cara de Edrei se ve molesta y triste.
# Texto original: escoria holds edrei's arm with a sad expression. edrei looks scared
# Traducción: Escoria sostiene el brazo de edrei con expresión triste. edrei parece asustado
# Texto original: escoria is turned back and looks at her left with a sad expression
# Traducción: Escoria se da vuelta y mira a su izquierda con expresión triste.
# Texto original: escoria smiles with a funny face
# Traducción: Escoria sonríe con una cara graciosa.
# Texto original: escoria and edrei are sitted on a ledge. escoria looks at her right with a sad expression. edrei is turned away
# Traducción: Escoria y edrei están sentados en una repisa. Escoria mira a su derecha con expresión triste. edrei es rechazado
# Texto original: a rock is on the floor with a shadow on it
# Traducción: Hay una piedra en el suelo con una sombra.
# Texto original: escoria looks back her with a sad expression. a village is in the background
# Traducción: Escoria la mira con expresión triste. un pueblo está al fondo
# Texto original: edrei's face looks upset and sad
# Traducción: La cara de Edrei se ve molesta y triste.
# Texto original: a hand holds a book
# Traducción: una mano sostiene un libro
# Texto original: edrei holds a magic wand and cast a spell. edrei looks scared
# Traducción: Edrei sostiene una varita mágica y lanza un hechizo. edrei parece asustado
# Texto original: edrei and escoria are walking holding their wands. escoria smiles and holds her wand
# Traducción: edrei y escoria caminan sosteniendo sus varitas. Escoria sonríe y sostiene su varita.
# Texto original: a man and a girl are walking throw a sandy beach
# Traducción: un hombre y una niña caminan por una playa de arena
# Texto original: a lot of marks on the floor
# Traducción: muchas marcas en el suelo
# Texto original: edrei looks scared at escoria's side. edrei looks surprised
# Traducción: Edrei mira asustado al lado de Escoria. edrei parece sorprendido
# Texto original: escoria turns her head back and look with a sad expression
# Traducción: Escoria vuelve la cabeza hacia atrás y mira con expresión triste.
# Texto original: a hand push away edrei. edrei falls against a wall
# Traducción: una mano empuja a edrei. edrei cae contra una pared
# Texto original: escoria lifts her magic wand. edrei looks scared and surprised. edrei looks surprised
# Traducción: Escoria levanta su varita mágica. Edrei parece asustado y sorprendido. edrei parece sorprendido
# Texto original: a horse is running in a arena with people watching
# Traducción: un caballo corre en una arena con la gente mirando
# Texto original: a boot with a cloack shows its teeth and has a pain expression
# Traducción: una bota con capa muestra los dientes y tiene expresión de dolor
# Texto original: escoria turns her head back and look with a sad expression
# Traducción: Escoria vuelve la cabeza hacia atrás y mira con expresión triste.
# Texto original: edrei's face looks shocked and surprised
# Traducción: El rostro de Edrei luce impactado y sorprendido.
# Texto original: escoria and edrei are turned back. edrei is turned back. edrei is turned back. edrei looks scared
# Traducción: Escoria y Edrei se dan la vuelta. Edrei se da la vuelta. Edrei se da la vuelta. Edrei parece asustado.
# Texto original: the letters of the alphabet are illuminated by a bright glow
# Traducción: las letras del alfabeto están iluminadas por un resplandor brillante
# Texto original: escoria and edrei are sitting at a table in front of a window. escoria and edrei are reading a book
# Traducción: Escoria y edrei están sentados en una mesa frente a una ventana. Escoria y Edrei están leyendo un libro.
# Texto original: escoria and edrei are laughing with a cheerful expression. escoria has an angry face. edrei looks scared
# Traducción: Escoria y edrei se ríen con expresión alegre. Escoria tiene cara de enfado. edrei parece asustado
# Texto original: escoria and edrei are sitting on a table with a happy expression. edrei looks surprised
# Traducción: Escoria y edrei están sentados en una mesa con expresión feliz. edrei parece sorprendido
# Texto original: escoria edrei and edrei are talking with a happy expression
# Traducción: escoria edrei y edrei están hablando con una expresión feliz.
# Texto original: a small sack is on the floor with a happy expression
# Traducción: Un pequeño saco está en el suelo con una expresión feliz.
# Texto original: edrei and escoria are sitting at a table. edrei and escoria are reading a book
# Traducción: edrei y escoria están sentados en una mesa. edrei y escoria están leyendo un libro
# Texto original: escoria puts her hand in edrei's shoulder. escoria puts her hand in edrei's shoulder.
# Traducción: Escoria pone su mano en el hombro de Edrei. Escoria pone su mano en el hombro de Edrei.
# Texto original: edrei and escoria are turned back. a letter is turned back. a hand holds a letter
# Traducción: edrei y escoria se dan la vuelta. una carta se devuelve. una mano sostiene una carta
# Texto original: edrei reads a book and talks with a curious expression
# Traducción: edrei lee un libro y habla con una expresión curiosa.
# Texto original: escoria holds a knife between her legs. escoria has a painfull face and blood is coming out her legs
# Traducción: Escoria sostiene un cuchillo entre sus piernas. Escoria tiene la cara dolorosa y le sale sangre de las piernas.
# Texto original: edrei and escoria are studying a book. escoria is writing and a man is writing on a table
# Traducción: Edrei y Escoria están estudiando un libro. Escoria está escribiendo y un hombre está escribiendo en una mesa.
# Texto original: escoria and edrei are turned back. edrei is turned back. escoria is turned back
# Traducción: escoria y edrei se dan la vuelta. Edrei se da la vuelta. la escoria esta de vuelta
# Texto original: a bald man with a beard and sharped ears is talking on a phone
# Traducción: un hombre calvo con barba y orejas afiladas está hablando por teléfono
# Texto original: nan
# Traducción:
# Texto original: a bald man with a gray beard and sharped ears stands with a happy expression
# Traducción: un hombre calvo con barba gris y orejas afiladas se encuentra con una expresión feliz
# Texto original: escoria turns her head back with a sad expression
# Traducción: Escoria vuelve la cabeza hacia atrás con expresión triste.
# Texto original: edrei and escoria are turned back and look at each other with a sad expression. edrei is turned back and has a sad expression
# Traducción: Edrei y Escoria están de espaldas y se miran con expresión triste. Edrei está de espaldas y tiene expresión triste.
# Texto original: edrei and escoria are sitted down. edrei and escoria are turned back. edrei and escoria are turned back
# Traducción: edrei y escoria están sentados. edrei y escoria se dan la vuelta. edrei y escoria se dan la vuelta
# Texto original: a bald man with a beard is standing in front of a burned building
# Traducción: un hombre calvo con barba está parado frente a un edificio quemado
# Texto original: the letters of the alphabet are glowing in a dark room
# Traducción: las letras del alfabeto brillan en una habitación oscura
