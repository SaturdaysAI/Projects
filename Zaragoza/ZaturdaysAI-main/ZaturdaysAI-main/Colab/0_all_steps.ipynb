# %% [markdown]
# # Card.io
#
# 1. Añadir un acceso directo a la carpeta 'Proyecto03':
#   * ir a Google Drive
#   * en el menú de la izquierda seleccionar 'Compartido conmigo'
#   * hacer click derecho sobre la carpeta 'Proyecto03'
#   * en el menú contextual seleccionar la opción 'Añadir acceso directo a drive'
#   * seleccionar 'Mi unidad'
#
# 2. Permitir que la libreria de Colab conecte con nuestro drive
#   * Al salir la ventana emergente autenticarse con la cuenta de Google (Gmail) y aceptar las condiciones.
#
# **NOTA**: ¿Tendrán otros usuarios acceso a los archivos de Drive?
#
# No, cada cuaderno es un objeto distinto en Drive con permisos de Drive distintos

# %%
# cargar datos
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Comprobamos que se puede acceder a los ficheros de drive, particularmente a los cuadernos del proyecto
! ls /content/drive/My\ Drive/Proyecto03/Notebooks_Proyecto
# Out:
# 0_all_steps.ipynb		Analisis_data_v1.0.ipynb
# 1_load_data.ipynb		Analisis_data_v3_1_JoseAntonio.ipynb
# 2_clean_data.ipynb		Cardio_3_Streamlit_Erick.py
# 3_data_analysis.ipynb		Cardio_analisis.ipynb
# 4_data_model.ipynb		Curso_PythonML_regresion_Soluciones.ipynb
# Analisis_data_v1.0_cesar.ipynb	resources
# Analisis_data_v1.0_erick.ipynb

# %% [markdown]
# ## Carga de datos

# %%
# Recuerda que, en este paso debes subir el archivo 'kaggle.json' que da acceso a los dataset con vuestra cuenta
# Si tienes dudas mira los pasos en '1. load_data.ipynb'
# %run /content/drive/My\ Drive/Proyecto03/Notebooks_Proyecto/1_load_data.ipynb
# Out:
# *******************************************************************************************************
#  Cargando los datos ....
#      <input type="file" id="files-f9d12929-0d2b-4ea7-bc0c-6a11562c059e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f9d12929-0d2b-4ea7-bc0c-6a11562c059e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# rm: cannot remove '/root/.kaggle/': No such file or directory
# ...
#   0% 0.00/742k [00:00<?, ?B/s]
# 100% 742k/742k [00:00<00:00, 48.5MB/s]
# Archive:  /content/datasets/cardiovascular-disease-dataset.zip
#   inflating: cardio_train.csv
# Datos cargados!
# *******************************************************************************************************

# %%
# Mover el fichero .csv al directorio de recursos del proyecto para poder tratarlo.
# ! cp /content/datasets/cardio_train.csv /content/drive/My\ Drive/Proyecto03/Notebooks_Proyecto/resources

# %% [markdown]
# ## Limpieza de datos

# %%
# %run /content/drive/My\ Drive/Proyecto03/Notebooks_Proyecto/2_clean_data.ipynb
# Out:
# *******************************************************************************************************
#  Limpiando los datos ....
# age: 8076
# gender: 2
# height: 109
# weight: 287
# ap_hi: 153
# ap_lo: 157
# cholesterol: 3
# gluc: 3
# smoke: 2
# alco: 2
# active: 2
# Datos limpios!
# *******************************************************************************************************

# %% [markdown]
# ## Análisis de datos

# %%
# %run /content/drive/My\ Drive/Proyecto03/Notebooks_Proyecto/3_data_analysis.ipynb
# Out:
# *******************************************************************************************************
#  Analizando los datos ....
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %% [markdown]
# ## Modelado de datos

# %%
# %run /content/drive/My\ Drive/Proyecto03/Notebooks_Proyecto/4_data_model.ipynb
# Out:
# *******************************************************************************************************
#  Generando el modelo ....
# (47739, 11) (47739,)
# (20460, 11) (20460,)
# Accuray on test set:0.71
# === Confusion Matrix ===
# [[7440 2966]
#  [3024 7030]]
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71     10406
#            1       0.70      0.70      0.70     10054
#
#     accuracy                           0.71     20460
#    macro avg       0.71      0.71      0.71     20460
# weighted avg       0.71      0.71      0.71     20460
# Start in: 2022-03-02 19:54:44.233835
# Fitting 3 folds for each of 200 candidates, totalling 600 fits
# Execution time: 0:06:20.355622
# End in: 2022-03-02 20:01:04.590297
# === Confusion Matrix ===
# [[7985 2421]
#  [3233 6821]]
# === Classification Report ===
#               precision    recall  f1-score   support
#
# ...
