# %%
# !pip install --upgrade tensorflow
# !pip install --upgrade keras
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Collecting tensorflow
#   Downloading tensorflow-2.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (589.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.8/589.8 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Collecting h5py>=3.10.0 (from tensorflow)
#   Downloading h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 104.3 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Collecting ml-dtypes~=0.3.1 (from tensorflow)
#   Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 86.9 MB/s eta 0:00:00
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow)
#   Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 101.8 MB/s eta 0:00:00
# Collecting keras>=3.0.0 (from tensorflow)
#   Downloading keras-3.3.3-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 76.9 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.0.0->tensorflow) (13.7.1)
# Collecting namex (from keras>=3.0.0->tensorflow)
#   Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Collecting optree (from keras>=3.0.0->tensorflow)
#   Downloading optree-0.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 38.6 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.6.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.0.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.0.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.2)
# Installing collected packages: namex, optree, ml-dtypes, h5py, tensorboard, keras, tensorflow
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
#     Uninstalling tensorboard-2.15.2:
#       Successfully uninstalled tensorboard-2.15.2
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.15.1 requires tensorflow<2.16,>=2.15, but you have tensorflow 2.16.1 which is incompatible.
# Successfully installed h5py-3.11.0 keras-3.3.3 ml-dtypes-0.3.2 namex-0.0.8 optree-0.11.0 tensorboard-2.16.2 tensorflow-2.16.1
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.3.3)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.25.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.11.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.3.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras) (4.12.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from google_drive_downloader import GoogleDriveDownloader as gdd
from sklearn.model_selection import train_test_split
import keras
import os
import shutil
import imghdr

# %%
print(os.listdir())
# Out:
# ['.config', 'drive', 'sample_data']

# %%
def detectar_corrupcion(directory):
    images_corruptas = []
    images_no_corruptas = []
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        if os.path.isfile(file_path):
            try:
                # Verificar el tipo de archivo de la imagen
                image_type = imghdr.what(file_path)
                if image_type and (image_type.lower() == "jpg" or image_type.lower() == "jpeg"):
                    # Intentar abrir la imagen
                    with Image.open(file_path) as img:
                        # Verificar si la imagen se puede cargar correctamente
                        img.load()
                        # Verificar el formato de compresión
                        if img.format == "JPEG":
                            images_no_corruptas.append(filename)
                else:
                    images_corruptas.append(filename)
            except Exception as e:
                images_corruptas.append(file_path)
    for corrupt_file in images_corruptas:
      corrupt_file_path = os.path.join(directory, corrupt_file)
      os.remove(corrupt_file_path)
      print(f"El archivo corrupto {corrupt_file} ha sido eliminado.")
    return images_corruptas

# %%
routes_list = [r"/content/drive/MyDrive/Tomates_proyecto/optimizado/train/Bacterial_spot",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/train/Early_blight",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/train/Late_blight",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/train/Leaf_Mold",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/train/Septoria_leaf_spot",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/train/Spider_mites_Two-spotted_spider_mite",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/train/Target_Spot",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/train/Tomato_Yellow_Leaf_Curl_Virus",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/train/Tomato_mosaic_virus",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/train/healthy",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/train/powdery_mildew",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/Bacterial_spot",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/Early_blight",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/Late_blight",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/Leaf_Mold",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/Septoria_leaf_spot",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/Spider_mites_Two-spotted_spider_mite",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/Target_Spot",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/Tomato_Yellow_Leaf_Curl_Virus",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/Tomato_mosaic_virus",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/healthy",
               r"/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/powdery_mildew"]

# %%
for directory in routes_list:
  print(detectar_corrupcion(directory))
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
for directory in routes_list:
  if os.path.isdir(directory):
    num_files = len([filename for filename in os.listdir(directory)])
    print(f"Number of files in '{directory}': {num_files}")
# Out:
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/train/Bacterial_spot': 2593
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/train/Early_blight': 2458
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/train/Late_blight': 3001
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/train/Leaf_Mold': 2504
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/train/Septoria_leaf_spot': 2882
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/train/Spider_mites_Two-spotted_spider_mite': 1717
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/train/Target_Spot': 1827
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/train/Tomato_Yellow_Leaf_Curl_Virus': 1792
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/train/Tomato_mosaic_virus': 1900
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/train/healthy': 2730
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/train/powdery_mildew': 500
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/Bacterial_spot': 735
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/Early_blight': 643
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/Late_blight': 792
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/Leaf_Mold': 739
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/Septoria_leaf_spot': 746
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/Spider_mites_Two-spotted_spider_mite': 435
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/Target_Spot': 457
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/Tomato_Yellow_Leaf_Curl_Virus': 498
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/Tomato_mosaic_virus': 584
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/healthy': 805
# Number of files in '/content/drive/MyDrive/Tomates_proyecto/optimizado/valid/powdery_mildew': 252

# %%
data_dir = "/content/drive/MyDrive/Tomates_proyecto/optimizado/train"

def database(data_dir, validation_split=0.2, seed=1534, batch_size=None):
    train_dataset = tf.keras.utils.image_dataset_from_directory(
        data_dir,
        validation_split=validation_split,
        subset='training',
        seed=seed,
        batch_size=batch_size,
        label_mode='int',
        image_size=(224, 224)
    )

    validation_dataset = tf.keras.utils.image_dataset_from_directory(
        data_dir,
        validation_split=validation_split,
        subset='validation',
        seed=seed,
        batch_size=batch_size,
        label_mode='int',
        image_size=(224, 224)
    )

    class_names = train_dataset.class_names
    num_classes = len(class_names)

    ds_info = {
        'num_classes': num_classes,
        'class_names': class_names
    }

    return train_dataset, validation_dataset, ds_info

train_dataset, validation_dataset, ds_info = database(data_dir)

print("Number of classes:", ds_info['num_classes'])
# Out:
# Found 23904 files belonging to 11 classes.
# Using 19124 files for training.
# Found 23904 files belonging to 11 classes.
# Using 4780 files for validation.
# Number of classes: 11

# %%
ds_info['class_names']
# Out:
# ['Bacterial_spot',
#  'Early_blight',
#  'Late_blight',
#  'Leaf_Mold',
#  'Septoria_leaf_spot',
#  'Spider_mites_Two-spotted_spider_mite',
#  'Target_Spot',
#  'Tomato_Yellow_Leaf_Curl_Virus',
#  'Tomato_mosaic_virus',
#  'healthy',
#  'powdery_mildew']

# %%
NUM_CLASSES = ds_info['num_classes']

# %%
def format_label(label):
  return ds_info['class_names'][label]

label_info = ds_info['class_names']
for i, (image, label) in enumerate(train_dataset.take(9)):
  ax = plt.subplot(5, 5, i + 1)
  plt.imshow(image.numpy().astype("uint8"))
  plt.title('{}'.format(format_label(label)))
  plt.axis('off')

# %%
from keras import layers


data_augmentation = tf.keras.Sequential([
    layers.RandomRotation(0.2),
    layers.RandomTranslation(0.2, 0.2),
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomContrast(0.2),
    layers.RandomZoom(0.2),
    layers.RandomBrightness(0.2),
    layers.RandomCrop(224, 224),
    layers.GaussianNoise(0.1)
])

# %%
for image, label in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        aug_img = data_augmentation(np.expand_dims(image.numpy(), axis=0))
        aug_img = np.array(aug_img)
        plt.imshow(aug_img[0].astype("uint8"))
        plt.title("{}".format(format_label(label)))
        plt.axis("off")

# %%
def preprocess_train(image, label):
    image = tf.expand_dims(image, axis=0)
    image = data_augmentation(image)
    image = tf.squeeze(image, axis=0)
    return image, label

def preprocess_validation(image, label):
    # En el conjunto de validación solo se normalizan las imágenes (si es necesario)
    return image, label

# Aplicar preprocesamiento a los conjuntos de datos
train_dataset = train_dataset.map(preprocess_train, num_parallel_calls=tf.data.AUTOTUNE)
validation_dataset = validation_dataset.map(preprocess_validation, num_parallel_calls=tf.data.AUTOTUNE)

train_dataset = train_dataset.batch(100).prefetch(buffer_size=tf.data.AUTOTUNE)
validation_dataset = validation_dataset.batch(100).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
for images, labels in train_dataset.take(1):  # Tomar solo un lote de datos
    print("Image batch shape:", images.shape)
    print("Label batch shape:", labels.shape)
# Out:
# Image batch shape: (100, 224, 224, 3)
# Label batch shape: (100,)

# %%
from keras.applications import ResNet50
from keras.layers import Dense, Flatten, GlobalAveragePooling2D
from keras.models import Model
from keras.optimizers import Adam
from keras import layers, models, regularizers
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.callbacks import ReduceLROnPlateau

# Definir el modelo ResNet50 con regularización
def create_resnet50_model(input_shape=(224, 224, 3), num_classes=ds_info['num_classes']):
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)

    x = base_model.output
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(1024, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)
    predictions = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs=base_model.input, outputs=predictions)

    for layer in base_model.layers:
        layer.trainable = False

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# Crear el modelo
model = create_resnet50_model()

# Definir los callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint('/content/drive/MyDrive/Tomates_proyecto/best_model.weights.h5', monitor='val_loss', save_best_only=True, save_weights_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=1e-10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Entrenar el modelo
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=100,
    callbacks=[early_stopping, checkpoint, reduce_lr]
)

# Cargar los mejores pesos y evaluar
model.load_weights('/content/drive/MyDrive/Tomates_proyecto/best_model.weights.h5')
loss, accuracy = model.evaluate(validation_dataset)
print(f'Best Validation accuracy: {accuracy * 100:.2f}%')
# Out:
# Epoch 1/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 878s 4s/step - accuracy: 0.2736 - loss: 15.9916 - val_accuracy: 0.6408 - val_loss: 13.1569 - learning_rate: 1.0000e-04
# Epoch 2/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 444ms/step - accuracy: 0.5436 - loss: 13.2665 - val_accuracy: 0.7065 - val_loss: 11.4815 - learning_rate: 1.0000e-04
# Epoch 3/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 89s 463ms/step - accuracy: 0.5990 - loss: 11.5699 - val_accuracy: 0.7444 - val_loss: 9.9955 - learning_rate: 1.0000e-04
# Epoch 4/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 445ms/step - accuracy: 0.6459 - loss: 10.1044 - val_accuracy: 0.7548 - val_loss: 8.7724 - learning_rate: 1.0000e-04
# Epoch 5/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 446ms/step - accuracy: 0.6626 - loss: 8.8441 - val_accuracy: 0.7600 - val_loss: 7.7041 - learning_rate: 1.0000e-04
# Epoch 6/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 444ms/step - accuracy: 0.6710 - loss: 7.7821 - val_accuracy: 0.7586 - val_loss: 6.7612 - learning_rate: 1.0000e-04
# Epoch 7/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 443ms/step - accuracy: 0.6917 - loss: 6.8347 - val_accuracy: 0.7789 - val_loss: 5.9239 - learning_rate: 1.0000e-04
# Epoch 8/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 446ms/step - accuracy: 0.7040 - loss: 6.0285 - val_accuracy: 0.7854 - val_loss: 5.2503 - learning_rate: 1.0000e-04
# Epoch 9/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 445ms/step - accuracy: 0.7097 - loss: 5.3556 - val_accuracy: 0.7927 - val_loss: 4.6379 - learning_rate: 1.0000e-04
# Epoch 10/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 445ms/step - accuracy: 0.7018 - loss: 4.7856 - val_accuracy: 0.7994 - val_loss: 4.1042 - learning_rate: 1.0000e-04
# Epoch 11/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 446ms/step - accuracy: 0.7320 - loss: 4.2351 - val_accuracy: 0.8008 - val_loss: 3.6665 - learning_rate: 1.0000e-04
# Epoch 12/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 445ms/step - accuracy: 0.7318 - loss: 3.8170 - val_accuracy: 0.8144 - val_loss: 3.2616 - learning_rate: 1.0000e-04
# Epoch 13/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 443ms/step - accuracy: 0.7433 - loss: 3.4071 - val_accuracy: 0.8136 - val_loss: 2.9583 - learning_rate: 1.0000e-04
# Epoch 14/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 446ms/step - accuracy: 0.7452 - loss: 3.0900 - val_accuracy: 0.8079 - val_loss: 2.6960 - learning_rate: 1.0000e-04
# Epoch 15/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 444ms/step - accuracy: 0.7514 - loss: 2.8066 - val_accuracy: 0.8123 - val_loss: 2.4323 - learning_rate: 1.0000e-04
# Epoch 16/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 447ms/step - accuracy: 0.7549 - loss: 2.5722 - val_accuracy: 0.8027 - val_loss: 2.2604 - learning_rate: 1.0000e-04
# Epoch 17/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 445ms/step - accuracy: 0.7520 - loss: 2.3754 - val_accuracy: 0.8178 - val_loss: 2.0526 - learning_rate: 1.0000e-04
# Epoch 18/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 443ms/step - accuracy: 0.7564 - loss: 2.1880 - val_accuracy: 0.8163 - val_loss: 1.8986 - learning_rate: 1.0000e-04
# Epoch 19/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 447ms/step - accuracy: 0.7631 - loss: 2.0202 - val_accuracy: 0.8213 - val_loss: 1.7549 - learning_rate: 1.0000e-04
# Epoch 20/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 445ms/step - accuracy: 0.7679 - loss: 1.8766 - val_accuracy: 0.8157 - val_loss: 1.6496 - learning_rate: 1.0000e-04
# Epoch 21/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 446ms/step - accuracy: 0.7761 - loss: 1.7480 - val_accuracy: 0.8328 - val_loss: 1.4963 - learning_rate: 1.0000e-04
# Epoch 22/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 444ms/step - accuracy: 0.7741 - loss: 1.6531 - val_accuracy: 0.8318 - val_loss: 1.4093 - learning_rate: 1.0000e-04
# Epoch 23/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 445ms/step - accuracy: 0.7777 - loss: 1.5516 - val_accuracy: 0.8318 - val_loss: 1.3507 - learning_rate: 1.0000e-04
# Epoch 24/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 85s 443ms/step - accuracy: 0.7779 - loss: 1.4883 - val_accuracy: 0.8473 - val_loss: 1.2337 - learning_rate: 1.0000e-04
# Epoch 25/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 85s 443ms/step - accuracy: 0.7773 - loss: 1.4158 - val_accuracy: 0.8412 - val_loss: 1.2009 - learning_rate: 1.0000e-04
# Epoch 26/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 445ms/step - accuracy: 0.7790 - loss: 1.3495 - val_accuracy: 0.8379 - val_loss: 1.1466 - learning_rate: 1.0000e-04
# Epoch 27/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 85s 441ms/step - accuracy: 0.7841 - loss: 1.2875 - val_accuracy: 0.8498 - val_loss: 1.0898 - learning_rate: 1.0000e-04
# Epoch 28/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 444ms/step - accuracy: 0.7851 - loss: 1.2397 - val_accuracy: 0.8433 - val_loss: 1.0687 - learning_rate: 1.0000e-04
# Epoch 29/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 445ms/step - accuracy: 0.7900 - loss: 1.2005 - val_accuracy: 0.8590 - val_loss: 0.9838 - learning_rate: 1.0000e-04
# Epoch 30/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 83s 430ms/step - accuracy: 0.7929 - loss: 1.1623 - val_accuracy: 0.8264 - val_loss: 1.0486 - learning_rate: 1.0000e-04
# Epoch 31/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 85s 444ms/step - accuracy: 0.7944 - loss: 1.1367 - val_accuracy: 0.8473 - val_loss: 0.9674 - learning_rate: 1.0000e-04
# Epoch 32/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 445ms/step - accuracy: 0.7932 - loss: 1.1051 - val_accuracy: 0.8439 - val_loss: 0.9499 - learning_rate: 1.0000e-04
# Epoch 33/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 444ms/step - accuracy: 0.7972 - loss: 1.0835 - val_accuracy: 0.8573 - val_loss: 0.9064 - learning_rate: 1.0000e-04
# Epoch 34/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 447ms/step - accuracy: 0.7976 - loss: 1.0513 - val_accuracy: 0.8485 - val_loss: 0.8960 - learning_rate: 1.0000e-04
# Epoch 35/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 84s 434ms/step - accuracy: 0.8053 - loss: 1.0171 - val_accuracy: 0.8320 - val_loss: 0.9192 - learning_rate: 1.0000e-04
# Epoch 36/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 446ms/step - accuracy: 0.8042 - loss: 0.9990 - val_accuracy: 0.8548 - val_loss: 0.8548 - learning_rate: 1.0000e-04
# Epoch 37/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 445ms/step - accuracy: 0.8013 - loss: 0.9928 - val_accuracy: 0.8533 - val_loss: 0.8434 - learning_rate: 1.0000e-04
# Epoch 38/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 443ms/step - accuracy: 0.8007 - loss: 0.9832 - val_accuracy: 0.8552 - val_loss: 0.8241 - learning_rate: 1.0000e-04
# Epoch 39/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 83s 429ms/step - accuracy: 0.8003 - loss: 0.9645 - val_accuracy: 0.8450 - val_loss: 0.8423 - learning_rate: 1.0000e-04
# Epoch 40/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 85s 442ms/step - accuracy: 0.8086 - loss: 0.9487 - val_accuracy: 0.8577 - val_loss: 0.8000 - learning_rate: 1.0000e-04
# Epoch 41/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 83s 428ms/step - accuracy: 0.7957 - loss: 0.9550 - val_accuracy: 0.8569 - val_loss: 0.8043 - learning_rate: 1.0000e-04
# Epoch 42/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 82s 429ms/step - accuracy: 0.7987 - loss: 0.9443 - val_accuracy: 0.8395 - val_loss: 0.8248 - learning_rate: 1.0000e-04
# Epoch 43/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 82s 429ms/step - accuracy: 0.8050 - loss: 0.9272 - val_accuracy: 0.8446 - val_loss: 0.8229 - learning_rate: 1.0000e-04
# Epoch 44/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 83s 430ms/step - accuracy: 0.8106 - loss: 0.9150 - val_accuracy: 0.8481 - val_loss: 0.8034 - learning_rate: 1.0000e-05
# Epoch 45/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 85s 442ms/step - accuracy: 0.8138 - loss: 0.8905 - val_accuracy: 0.8513 - val_loss: 0.7835 - learning_rate: 1.0000e-05
# Epoch 46/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 443ms/step - accuracy: 0.8134 - loss: 0.8967 - val_accuracy: 0.8556 - val_loss: 0.7651 - learning_rate: 1.0000e-05
# Epoch 47/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 444ms/step - accuracy: 0.8219 - loss: 0.8686 - val_accuracy: 0.8596 - val_loss: 0.7558 - learning_rate: 1.0000e-05
# Epoch 48/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 444ms/step - accuracy: 0.8257 - loss: 0.8534 - val_accuracy: 0.8646 - val_loss: 0.7430 - learning_rate: 1.0000e-05
# Epoch 49/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 443ms/step - accuracy: 0.8224 - loss: 0.8501 - val_accuracy: 0.8628 - val_loss: 0.7392 - learning_rate: 1.0000e-05
# Epoch 50/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 85s 442ms/step - accuracy: 0.8265 - loss: 0.8343 - val_accuracy: 0.8657 - val_loss: 0.7227 - learning_rate: 1.0000e-05
# Epoch 51/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 445ms/step - accuracy: 0.8292 - loss: 0.8331 - val_accuracy: 0.8644 - val_loss: 0.7206 - learning_rate: 1.0000e-05
# Epoch 52/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 85s 443ms/step - accuracy: 0.8287 - loss: 0.8216 - val_accuracy: 0.8690 - val_loss: 0.7126 - learning_rate: 1.0000e-05
# Epoch 53/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 83s 430ms/step - accuracy: 0.8350 - loss: 0.8093 - val_accuracy: 0.8672 - val_loss: 0.7127 - learning_rate: 1.0000e-05
# Epoch 54/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 85s 443ms/step - accuracy: 0.8330 - loss: 0.8032 - val_accuracy: 0.8707 - val_loss: 0.6943 - learning_rate: 1.0000e-05
# Epoch 55/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 83s 428ms/step - accuracy: 0.8368 - loss: 0.8002 - val_accuracy: 0.8701 - val_loss: 0.6973 - learning_rate: 1.0000e-05
# Epoch 56/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 83s 431ms/step - accuracy: 0.8378 - loss: 0.7947 - val_accuracy: 0.8697 - val_loss: 0.6968 - learning_rate: 1.0000e-05
# Epoch 57/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 85s 444ms/step - accuracy: 0.8361 - loss: 0.7881 - val_accuracy: 0.8703 - val_loss: 0.6896 - learning_rate: 1.0000e-05
# Epoch 58/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 443ms/step - accuracy: 0.8350 - loss: 0.7839 - val_accuracy: 0.8715 - val_loss: 0.6850 - learning_rate: 1.0000e-05
# Epoch 59/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 85s 443ms/step - accuracy: 0.8319 - loss: 0.7908 - val_accuracy: 0.8755 - val_loss: 0.6749 - learning_rate: 1.0000e-05
# Epoch 60/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 85s 443ms/step - accuracy: 0.8380 - loss: 0.7634 - val_accuracy: 0.8776 - val_loss: 0.6689 - learning_rate: 1.0000e-05
# Epoch 61/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 443ms/step - accuracy: 0.8366 - loss: 0.7713 - val_accuracy: 0.8774 - val_loss: 0.6587 - learning_rate: 1.0000e-05
# Epoch 62/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 83s 429ms/step - accuracy: 0.8380 - loss: 0.7593 - val_accuracy: 0.8774 - val_loss: 0.6588 - learning_rate: 1.0000e-05
# Epoch 63/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 83s 432ms/step - accuracy: 0.8423 - loss: 0.7528 - val_accuracy: 0.8776 - val_loss: 0.6587 - learning_rate: 1.0000e-05
# Epoch 64/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 85s 443ms/step - accuracy: 0.8398 - loss: 0.7553 - val_accuracy: 0.8736 - val_loss: 0.6497 - learning_rate: 1.0000e-05
# Epoch 65/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 447ms/step - accuracy: 0.8403 - loss: 0.7490 - val_accuracy: 0.8755 - val_loss: 0.6489 - learning_rate: 1.0000e-05
# Epoch 66/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 443ms/step - accuracy: 0.8404 - loss: 0.7404 - val_accuracy: 0.8782 - val_loss: 0.6392 - learning_rate: 1.0000e-05
# Epoch 67/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 445ms/step - accuracy: 0.8449 - loss: 0.7331 - val_accuracy: 0.8789 - val_loss: 0.6366 - learning_rate: 1.0000e-05
# Epoch 68/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 85s 442ms/step - accuracy: 0.8381 - loss: 0.7517 - val_accuracy: 0.8793 - val_loss: 0.6335 - learning_rate: 1.0000e-05
# Epoch 69/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 443ms/step - accuracy: 0.8467 - loss: 0.7234 - val_accuracy: 0.8791 - val_loss: 0.6305 - learning_rate: 1.0000e-05
# Epoch 70/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 446ms/step - accuracy: 0.8445 - loss: 0.7242 - val_accuracy: 0.8799 - val_loss: 0.6286 - learning_rate: 1.0000e-05
# Epoch 71/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 446ms/step - accuracy: 0.8458 - loss: 0.7094 - val_accuracy: 0.8803 - val_loss: 0.6265 - learning_rate: 1.0000e-05
# Epoch 72/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 445ms/step - accuracy: 0.8449 - loss: 0.7136 - val_accuracy: 0.8797 - val_loss: 0.6231 - learning_rate: 1.0000e-05
# Epoch 73/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 444ms/step - accuracy: 0.8464 - loss: 0.7076 - val_accuracy: 0.8816 - val_loss: 0.6189 - learning_rate: 1.0000e-05
# Epoch 74/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 444ms/step - accuracy: 0.8411 - loss: 0.7145 - val_accuracy: 0.8808 - val_loss: 0.6107 - learning_rate: 1.0000e-05
# Epoch 75/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 85s 442ms/step - accuracy: 0.8460 - loss: 0.7213 - val_accuracy: 0.8820 - val_loss: 0.6075 - learning_rate: 1.0000e-05
# Epoch 76/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 446ms/step - accuracy: 0.8441 - loss: 0.7084 - val_accuracy: 0.8851 - val_loss: 0.6043 - learning_rate: 1.0000e-05
# Epoch 77/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 85s 443ms/step - accuracy: 0.8480 - loss: 0.6863 - val_accuracy: 0.8841 - val_loss: 0.5974 - learning_rate: 1.0000e-05
# Epoch 78/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 83s 429ms/step - accuracy: 0.8504 - loss: 0.6855 - val_accuracy: 0.8805 - val_loss: 0.6028 - learning_rate: 1.0000e-05
# Epoch 79/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 83s 429ms/step - accuracy: 0.8494 - loss: 0.6904 - val_accuracy: 0.8803 - val_loss: 0.6011 - learning_rate: 1.0000e-05
# Epoch 80/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 85s 442ms/step - accuracy: 0.8492 - loss: 0.6886 - val_accuracy: 0.8810 - val_loss: 0.5942 - learning_rate: 1.0000e-05
# Epoch 81/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 447ms/step - accuracy: 0.8452 - loss: 0.6856 - val_accuracy: 0.8818 - val_loss: 0.5860 - learning_rate: 1.0000e-05
# Epoch 82/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 443ms/step - accuracy: 0.8423 - loss: 0.6848 - val_accuracy: 0.8866 - val_loss: 0.5756 - learning_rate: 1.0000e-05
# Epoch 83/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 83s 429ms/step - accuracy: 0.8507 - loss: 0.6821 - val_accuracy: 0.8877 - val_loss: 0.5757 - learning_rate: 1.0000e-05
# Epoch 84/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 85s 442ms/step - accuracy: 0.8570 - loss: 0.6548 - val_accuracy: 0.8879 - val_loss: 0.5731 - learning_rate: 1.0000e-05
# Epoch 85/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 443ms/step - accuracy: 0.8506 - loss: 0.6693 - val_accuracy: 0.8885 - val_loss: 0.5649 - learning_rate: 1.0000e-05
# Epoch 86/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 444ms/step - accuracy: 0.8530 - loss: 0.6617 - val_accuracy: 0.8925 - val_loss: 0.5546 - learning_rate: 1.0000e-05
# Epoch 87/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 444ms/step - accuracy: 0.8478 - loss: 0.6658 - val_accuracy: 0.8916 - val_loss: 0.5498 - learning_rate: 1.0000e-05
# Epoch 88/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 83s 430ms/step - accuracy: 0.8526 - loss: 0.6649 - val_accuracy: 0.8891 - val_loss: 0.5500 - learning_rate: 1.0000e-05
# Epoch 89/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 83s 429ms/step - accuracy: 0.8492 - loss: 0.6572 - val_accuracy: 0.8904 - val_loss: 0.5530 - learning_rate: 1.0000e-05
# Epoch 90/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 86s 446ms/step - accuracy: 0.8524 - loss: 0.6491 - val_accuracy: 0.8910 - val_loss: 0.5469 - learning_rate: 1.0000e-05
# Epoch 91/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 85s 442ms/step - accuracy: 0.8560 - loss: 0.6516 - val_accuracy: 0.8883 - val_loss: 0.5426 - learning_rate: 1.0000e-05
# Epoch 92/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 84s 434ms/step - accuracy: 0.8531 - loss: 0.6536 - val_accuracy: 0.8877 - val_loss: 0.5495 - learning_rate: 1.0000e-05
# Epoch 93/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 83s 431ms/step - accuracy: 0.8551 - loss: 0.6441 - val_accuracy: 0.8849 - val_loss: 0.5493 - learning_rate: 1.0000e-05
# Epoch 94/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 85s 444ms/step - accuracy: 0.8528 - loss: 0.6443 - val_accuracy: 0.8910 - val_loss: 0.5399 - learning_rate: 1.0000e-05
# Epoch 95/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 84s 434ms/step - accuracy: 0.8519 - loss: 0.6455 - val_accuracy: 0.8837 - val_loss: 0.5507 - learning_rate: 1.0000e-05
# Epoch 96/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 83s 433ms/step - accuracy: 0.8551 - loss: 0.6397 - val_accuracy: 0.8847 - val_loss: 0.5429 - learning_rate: 1.0000e-05
# Epoch 97/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 83s 431ms/step - accuracy: 0.8534 - loss: 0.6423 - val_accuracy: 0.8841 - val_loss: 0.5428 - learning_rate: 1.0000e-05
# Epoch 98/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 83s 431ms/step - accuracy: 0.8539 - loss: 0.6266 - val_accuracy: 0.8843 - val_loss: 0.5436 - learning_rate: 1.0000e-06
# Epoch 99/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 83s 433ms/step - accuracy: 0.8531 - loss: 0.6368 - val_accuracy: 0.8837 - val_loss: 0.5447 - learning_rate: 1.0000e-06
# Epoch 100/100
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 83s 430ms/step - accuracy: 0.8510 - loss: 0.6339 - val_accuracy: 0.8839 - val_loss: 0.5440 - learning_rate: 1.0000e-06
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 140ms/step - accuracy: 0.8918 - loss: 0.5418
# Best Validation accuracy: 89.10%

# %%
# Guardar los pesos del modelo
model.save_weights('/content/drive/MyDrive/Tomates_proyecto/resnet50_weights.weights.h5')
print("Model weights saved successfully in Google Drive.")

# Guardar el modelo completo en un archivo .h5
model.save('/content/drive/MyDrive/Tomates_proyecto/resnet50_model.h5')
print("Model saved successfully in Google Drive.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model weights saved successfully in Google Drive.
# Model saved successfully in Google Drive.

# %%
# Gráficas de precisión y pérdida
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()
