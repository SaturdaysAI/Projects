# %% [markdown]
# ### Load Data

# %%
# !pip install bb-tools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !ls drive/MyDrive/SaturdayAI/EEG_project/data/rubert/Rubert_mordida_1/EEG.csv
# Out:
# drive/MyDrive/SaturdayAI/EEG_project/data/rubert/Rubert_mordida_1/EEG.csv

# %%
import pandas as pd

#eeg_file = "../../data/Rubert_14_may/Rubert_mordida_1/EEG.csv"
eeg_file_jaw = "drive/MyDrive/SaturdayAI/EEG_project/data/rubert/Rubert_mordida_1/EEG.csv"
eeg_file_jaw_2 = "drive/MyDrive/SaturdayAI/EEG_project/data/rubert/Rubert_mordida_2/EEG.csv"

df_jaw = pd.read_csv(eeg_file_jaw)
df_jaw_2 = pd.read_csv(eeg_file_jaw_2)
print(df_jaw.shape)
df_jaw.head()
# Out:
# (20712, 20)
#       timestamp  sequence  battery  flags      EEG-ch1      EEG-ch2  \
# 0  153804687683     16336       -2      0 -2553.890054 -6876.865884
# 1  153804687683     16336       -2      0 -2557.710711 -6880.297175
# 2  153804687683     16336       -2      0 -2570.961333 -6885.176421
# 3  153804687683     16336       -2      0 -2585.039358 -6887.330103
# 4  153804687683     16336       -2      0 -2573.200189 -6886.064663
#
#         EEG-ch3     EEG-ch4       EEG-ch5      EEG-ch6       EEG-ch7  \
# 0  31106.838605  214.528663  22527.894451  8132.718209  21134.279463
# 1  31105.195966  214.772017  22528.880034  8132.827718  21137.443064
# 2  31096.520398  210.002279  22524.438825  8130.528023  21134.948686
# 3  31091.774996  201.935096  22518.805181  8127.899801  21129.205533
# 4  31095.473976  200.523644  22517.126039  8126.330168  21127.404714
#
#         EEG-ch8       EEG-ch9     EEG-ch10      EEG-ch11      EEG-ch12  \
# ...

# %%
#eeg_file = "../../data/Rubert_14_may/Rubert_mordida_1/EEG.csv"
eeg_file_left_blink = "drive/MyDrive/SaturdayAI/EEG_project/data/rubert/Rubert_ojo_izdo_1/EEG.csv"
eeg_file_left_blink_2 = "drive/MyDrive/SaturdayAI/EEG_project/data/rubert/Rubert_ojo_izdo_2/EEG.csv"

df_left_blink = pd.read_csv(eeg_file_left_blink)
df_left_blink_2 = pd.read_csv(eeg_file_left_blink_2)
print(df_left_blink.shape)
df_left_blink.head()
# Out:
# (20544, 20)
#       timestamp  sequence  battery  flags      EEG-ch1      EEG-ch2  \
# 0  153542513428     11491       -2      0 -2253.104588 -7348.631825
# 1  153542513428     11491       -2      0 -2246.874728 -7346.538982
# 2  153542513428     11491       -2      0 -2238.673700 -7346.125280
# 3  153542513428     11491       -2      0 -2232.602019 -7349.313216
# 4  153542513428     11491       -2      0 -2240.523190 -7352.391644
#
#         EEG-ch3     EEG-ch4       EEG-ch5       EEG-ch6       EEG-ch7  \
# 0  30867.755530  721.459248  23027.037710  10291.620488  21888.567156
# 1  30870.979970  720.254646  23028.181473  10292.606072  21887.374722
# 2  30877.246333  724.355160  23030.103969  10293.762003  21887.009691
# 3  30881.967400  728.163649  23032.087304  10293.968854  21888.798343
# 4  30877.733041  724.330824  23029.860615  10293.019773  21888.226461
#
#         EEG-ch8       EEG-ch9     EEG-ch10      EEG-ch11      EEG-ch12  \
# ...

# %%
eeg_file_rigth_blink = "drive/MyDrive/SaturdayAI/EEG_project/data/rubert/Rubert_ojo_dcho_1/EEG.csv"
eeg_file_rigth_blink_2 = "drive/MyDrive/SaturdayAI/EEG_project/data/rubert/rubert_ojo_dcho_2/EEG.csv"

df_rigth_blink = pd.read_csv(eeg_file_rigth_blink)
df_rigth_blink_2 = pd.read_csv(eeg_file_rigth_blink_2)

# %%
#datos de alba mordida y ojos
eeg_file_miguel_jaw = "drive/MyDrive/SaturdayAI/EEG_project/data/alba/Alba_muerde_1/EEG.csv"
eeg_file_alba_rigth_blink = "drive/MyDrive/SaturdayAI/EEG_project/data/alba/Alba_ojo_dcho_1/EEG.csv"
eeg_file_alba_left_blink = "drive/MyDrive/SaturdayAI/EEG_project/data/alba/Alba_ojo_izq_1/EEG.csv"

df_alba_jaw = pd.read_csv(eeg_file_alba_rigth_blink)
df_alba_rigth_blink = pd.read_csv(eeg_file_alba_rigth_blink)
df_alba_left_blink = pd.read_csv(eeg_file_alba_left_blink)

# %%
#datos de miguel
eeg_file_miguel_jaw = "drive/MyDrive/SaturdayAI/EEG_project/data/Miguel_28_may/Miguel_mordida_1/EEG.csv"
eeg_file_miguel_jaw_2 = "drive/MyDrive/SaturdayAI/EEG_project/data/Miguel_28_may/Miguel_mordida_2/EEG.csv"

eeg_file_miguel_rigth_blink= "drive/MyDrive/SaturdayAI/EEG_project/data/Miguel_28_may/Miguel_ojo_dcho_1/EEG.csv"
eeg_file_miguel_rigth_blink_2 = "drive/MyDrive/SaturdayAI/EEG_project/data/Miguel_28_may/Miguel_ojo_dcho_2/EEG.csv"

eeg_file_miguel_left_blink= "drive/MyDrive/SaturdayAI/EEG_project/data/Miguel_28_may/Miguel_ojo_izqo_1/EEG.csv"
eeg_file_miguel_left_blink_2 = "drive/MyDrive/SaturdayAI/EEG_project/data/Miguel_28_may/Miguel_ojo_izqo_2/EEG.csv"


df_miguel_jaw = pd.read_csv(eeg_file_miguel_jaw)
df_miguel_jaw_2 = pd.read_csv(eeg_file_miguel_jaw_2)

df_miguel_rigth_blink = pd.read_csv(eeg_file_miguel_rigth_blink)
df_miguel_rigth_blink_2= pd.read_csv(eeg_file_miguel_rigth_blink_2)

df_miguel_left_blink = pd.read_csv(eeg_file_miguel_left_blink)
df_miguel_left_blink_2 = pd.read_csv(eeg_file_miguel_left_blink_2)

# %%
#rubert
df_jaw.plot(subplots=True, figsize=(16, 16), title="rubert_jaw");
df_jaw_2.plot(subplots=True, figsize=(16, 16), title="rubert_jaw_2");

df_left_blink.plot(subplots=True, figsize=(16, 16), title="rubert_left_blink"); # tiene menos muestras y visualmente es mas dificil de comparar
#df_rigth_blink.plot(subplots=True, figsize=(16, 16), title="rubert_rigth_blink");

#df_left_blink_2.plot(subplots=True, figsize=(16, 16), title="rubert_left_blink_2");# tiene menos muestras y visualmente es mas dificil de comparar
df_rigth_blink_2.plot(subplots=True, figsize=(16, 16), title="rubert_rigth_blink_2");

#Alba
df_alba_jaw.plot(subplots=True, figsize=(16, 16), title="alba_jaw");
df_alba_rigth_blink.plot(subplots=True, figsize=(16, 16), title="alba_rigth_blink");
df_alba_left_blink.plot(subplots=True, figsize=(16, 16), title="alba_left_blink");

#Miguel
df_miguel_jaw.plot(subplots=True, figsize=(16, 16), title="miguel_jaw");
df_miguel_jaw_2.plot(subplots=True, figsize=(16, 16), title="miguel_jaw_2");

df_miguel_rigth_blink.plot(subplots=True, figsize=(16, 16), title="miguel_rigth_blink");
df_miguel_rigth_blink_2.plot(subplots=True, figsize=(16, 16), title="miguel_rigth_blink_2");

df_miguel_left_blink.plot(subplots=True, figsize=(16, 16), title="miguel_left_blink");
df_miguel_left_blink_2.plot(subplots=True, figsize=(16, 16), title="miguel_left_blink_2");

# %% [markdown]
# ### Loading Data with BBT functions to operate on Frequency

# %%
# !pip install mne
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 7.5 MB 14.1 MB/s
# ...

# %% [markdown]
# ### BBT Functions

# %%
import mne
import pandas as pd
import numpy as np
from math import floor
from sklearn.preprocessing import StandardScaler, MinMaxScaler, Normalizer, MaxAbsScaler



def bbt_read_csv(eeg_csv, channels, sfreq = 256, montage = 'standard_1020', useless_cols = ['timestamp', 'sequence', 'battery', 'flags']):
  df = pd.read_csv(eeg_csv)
  df_mne = df.drop(useless_cols, axis=1)

  # Transpose the matrix because MNE expects it like that
  data_mne = df_mne.to_numpy().transpose()

  # Scale the data
  # data_mne = data_mne / 1000000

  # Create MNE Raw's Info object
  info_mne = mne.create_info(
      #ch_names=list(df_mne.columns),
      ch_names=channels,
      ch_types='eeg',
      sfreq=sfreq)

  bbt_raw = mne.io.RawArray(data_mne, info_mne)
  ten_twenty_montage = mne.channels.make_standard_montage(montage)

  raw = bbt_raw.copy().set_montage(ten_twenty_montage)
  return raw

def high_low_filter_notches(raw, fmin = 0.5, fmax = 100, fnotch = 50.):
  '''Apply High/low filters and notch filters to raw data:
  - raw [mne.io.raw object]: raw data
  - fmin [float]: high pass filter
  - fmax [float]: low pass filter
  '''
  fig = raw.plot_psd(fmin = 0, fmax = fmax + 100, average=False, tmin = 0, tmax = 250)
  
  raw.filter(l_freq = fmin, h_freq = fmax, method = 'iir')
  powerEEG = raw.plot_psd(fmin = 0, fmax = 200, average=False, tmin = 0, tmax = 250)
  timeEEG = raw.plot(start = 0., duration = 250., scalings=0.5e-3, remove_dc=True)
  
  raw.notch_filter(fnotch, fir_design='firwin')
  powerEEG = raw.plot_psd(fmin = 0, fmax = 200, average=False, tmin = 0, tmax = 250)
  timeEEG = raw.plot(start = 0., duration = 250., scalings=0.5e-3, remove_dc=True)
  
  return raw

def interpolate_bat_electrodes(raw, bad_channels_list):
  raw.info['bads'] = bad_channels_list
  
  print('Bad electrodes: ', raw.info['bads'])
  raw.interpolate_bads(reset_bads=False)
  
  return raw

def epochs_around_false_events(raw, event_duration= 1., criteria = 1.3e-4, eventid = 333):
  events = mne.make_fixed_length_events(raw, id = eventid, duration = event_duration)
  
  reject_criteria = dict(eeg = criteria)

  epochs = mne.Epochs(raw, events, event_id = 333, tmin=-0.2, tmax=0.5,
                      reject=reject_criteria, preload=True)

  fig = epochs.plot(scalings=0.5e-4, block=True)
  
  epochs.plot_image()
  
  return epochs

def filters(raw, fmin=0.5, fmax=100., notch=50., sampling_rate=250, fir_design='firwin'):
    '''Apply high/low-pass and notch filters:

        === Args ===
        * raw - mne Raw object: object to apply filters on
        * fmin, fmax - float: bandpass frequencies
        * notch - float: powerline (AC current) frequecy
        * ny_freq - float: Nyquist frequency. Half of the sampling rate
        * fir_design: str: Notch filter type. See mne doc for more details
        * sampling_rate - int, float: sampling rate of the measured data

        === Returns ===
        * raw_c - mne Raw object: Processed Raw copy
        '''
    raw_c = raw.copy()
    raw_c.filter(l_freq=fmin, h_freq=fmax)
    raw_c.notch_filter(np.arange(notch, sampling_rate / 2, notch), fir_design=fir_design)
    return raw_c


def signal_df_to_np(dataframe, chunk_size=100, n_channels=16):
    n_chunks = floor(dataframe.shape[0] / chunk_size)

    windows = np.ndarray(shape=(n_channels, n_chunks, chunk_size), dtype=float)

    channels_array = []
    for i in range(1, n_channels + 1):
        channels_array.append("EEG-ch" + str(i))

    channels_as_pd = dataframe[channels_array].to_numpy()
    # shape --> (samplesChannel, nChannels)

    for iChannel in range(n_channels):
        for iChunk in range(n_chunks):
            for iSample in range(chunk_size):
                idf = (iChunk * chunk_size) + iSample
                windows[iChannel][iChunk][iSample] = channels_as_pd[idf][iChannel]

    # shape --> (channels, windows, samples)
    return windows




def channels_to_list_df_five_sec_window(channels_data, artifact_label):
    # shape --> (channels, windows, samples)

    channels_list_df = []

    for channelData in channels_data:
        channel_data_map = {'label': []}

        for iWindow, window in enumerate(channelData):
            even = (iWindow % 2) == 0
            label = artifact_label if (even and iWindow != 0) else "pause"
            channel_data_map['label'].append(label)

            for iSample, sample in enumerate(window):
                if iSample in channel_data_map:
                    channel_data_map[iSample].append(sample)
                else:
                    channel_data_map[iSample] = [sample]

        channel_data_df = pd.DataFrame(channel_data_map)
        channels_list_df.append(channel_data_df)
        # df.columns = ['window', 'label']

    # array --> df(window, sample) + last column label
    return channels_list_df

def channels_to_list_df_two_and_a_half_sec_window(channels_data, artifact_label):
    # shape --> (channels, windows, samples)

    channels_list_df = []

    for channelData in channels_data:
        channel_data_map = {'label': []}

        for iWindow, window in enumerate(channelData):
            multiple_of_four = (iWindow % 4) == 0
            label = artifact_label if (multiple_of_four and iWindow != 0) else "pause"
            channel_data_map['label'].append(label)

            for iSample, sample in enumerate(window):
                if iSample in channel_data_map:
                    channel_data_map[iSample].append(sample)
                else:
                    channel_data_map[iSample] = [sample]

        channel_data_df = pd.DataFrame(channel_data_map)
        channels_list_df.append(channel_data_df)
        # df.columns = ['window', 'label']

    # array --> df(window, sample) + last column label
    return channels_list_df

def channels_to_list_df2(channels_data, artifact_label):
    # Ventanas de 2,5 segundos
    # shape --> (channels, windows, samples)

    channels_list_df = []

    for channelData in channels_data:
        channel_data_map = {'label': []}

        for iWindow, window in enumerate(channelData):
            multiple_of_four = (iWindow % 4) == 0
            label = artifact_label if (multiple_of_four and iWindow != 0) else "pause"
            channel_data_map['label'].append(label)

            for iSample, sample in enumerate(window):
                if iSample in channel_data_map:
                    channel_data_map[iSample].append(sample)
                else:
                    channel_data_map[iSample] = [sample]

        channel_data_df = pd.DataFrame(channel_data_map)
        channels_list_df.append(channel_data_df)
        # df.columns = ['window', 'label']

    # array --> df(window, sample) + last column label
    return channels_list_df


def bbt_signal_raw_to_windows(eeg_data, chunk_size=100, n_channels=16):
    n_chunks = floor(eeg_data.shape[1] / chunk_size)

    windows = np.ndarray(shape=(n_channels, n_chunks, chunk_size), dtype=float)

    # shape --> (nChannels, samplesChannel)

    for iChannel in range(n_channels):
        for iChunk in range(n_chunks):
            for iSample in range(chunk_size):
                idf = (iChunk * chunk_size) + iSample
                windows[iChannel][iChunk][iSample] = eeg_data[iChannel][idf]

    # shape --> (channels, windows, samples)
    return windows

def bbt_signal_raw_to_windows_with_scaler(eeg_data, chunk_size=100, n_channels=16, scaler = 'MaxAbs'):
    n_chunks = floor(eeg_data.shape[1] / chunk_size)

    windows = np.ndarray(shape=(n_channels, n_chunks, chunk_size), dtype=float)

    # scaler
    if scaler == "MaxAbs":
      print("MaxAbs scaler")
      scaler = MaxAbsScaler()
      scaled_eeg_data = scaler.fit_transform(eeg_data)
    elif scaler == "Standard":
      scaler = StandardScaler()
      scaled_eeg_data = scaler.fit_transform(eeg_data)
    elif scaler == "MinMax" :
      scaler = MinMaxScaler()
      scaled_eeg_data = scaler.fit_transform(eeg_data)
    else: 
      print("no scaler")
      scaled_eeg_data = eeg_data

    # shape --> (nChannels, samplesChannel)

    for iChannel in range(n_channels):
        for iChunk in range(n_chunks):
            for iSample in range(chunk_size):
                idf = (iChunk * chunk_size) + iSample
                windows[iChannel][iChunk][iSample] = scaled_eeg_data[iChannel][idf]

    # shape --> (channels, windows, samples)
    return windows

# %%
#import bbtools as bbt

raw_rubert_jaw = bbt_read_csv(eeg_file_jaw, ['Fp1', 'Fp2', 'F3', 'F4', 'C1', 'C3', 'C2', 'C4', 'CP1', 'CP3', 'CP2', 'CP4', 'Cz', 'O1', 'O2', 'Pz'])
raw_rubert_left_blink = bbt_read_csv(eeg_file_left_blink, ['Fp1', 'Fp2', 'F3', 'F4', 'C1', 'C3', 'C2', 'C4', 'CP1', 'CP3', 'CP2', 'CP4', 'Cz', 'O1', 'O2', 'Pz'])
# Out:
# Creating RawArray with float64 data, n_channels=16, n_times=20712
#     Range : 0 ... 20711 =      0.000 ...    80.902 secs
# Ready.
# Creating RawArray with float64 data, n_channels=16, n_times=20544
#     Range : 0 ... 20543 =      0.000 ...    80.246 secs
# Ready.

# %%
plot_raw_jaw = raw_rubert_jaw.plot_psd(fmin = 0, fmax = 128, average=False, tmin = 0, tmax = 120)
plot_raw_left_blink = raw_rubert_left_blink.plot_psd(fmin = 0, fmax = 128, average=False, tmin = 0, tmax = 120)

#plot_raw = raw_rubert.plot_psd(fmin = 0, fmax = 128, average=True, tmin = 0, tmax = 120)s
#plot_raw = raw_rubert.plot_psd()
# Out:
# Effective window size : 8.000 (s)
# <MNELineFigure size 720x252 with 2 Axes>
# Effective window size : 8.000 (s)
# <MNELineFigure size 720x252 with 2 Axes>

# %%
filtered_rubert_jaw = filters(raw_rubert_jaw)
plot_filtered_jaw = filtered_rubert_jaw.plot_psd(fmin = 0, fmax = 128, average=False, tmin = 0, tmax = 120)

filtered_rubert_left_blink = filters(raw_rubert_left_blink)
plot_filtered_left_blink = filtered_rubert_left_blink.plot_psd(fmin = 0, fmax = 128, average=False, tmin = 0, tmax = 120)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 1691 samples (6.605 sec)
#
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 0.50 Hz
# - Upper transition bandwidth: 0.50 Hz
# - Filter length: 1691 samples (6.605 sec)
#
# ...

# %% [markdown]
# ## Slicing into smaller temporal windows of 2.5 seconds, and scaling the data

# %%
sampling_rate = 256
window_time = 2.5 # segs
window_size = int(window_time * sampling_rate)
n_channels = 16

eeg_data_rubert_jaw = filtered_rubert_jaw['data'][0] # datos de los 16 canales en formato numpy array
eeg_data_rubert_left_blink = filtered_rubert_left_blink['data'][0]

#channelsData = bbt_signal_raw_to_windows(eeg_data_rubert_jaw, window_size, n_channels)
channelsData_rubert_jaw = bbt_signal_raw_to_windows_with_scaler(eeg_data_rubert_jaw, window_size, n_channels)
channelsData_rubert_left_blik = bbt_signal_raw_to_windows_with_scaler(eeg_data_rubert_left_blink, window_size, n_channels)

print("channels, windows, samples")
print("---SHAPE jaw---")
print(channelsData_rubert_jaw.shape)
print("---DATA jaw---")
#print(channelsData_jaw)

print("---------------------")

print("---SHAPE left blink---")
print(channelsData_rubert_left_blik.shape)
print("---DATA left blink---")
#print(channelsData_jaw)
# Out:
# MaxAbs scaler
# MaxAbs scaler
# channels, windows, samples
# ---SHAPE jaw---
# (16, 32, 640)
# ---DATA jaw---
# ---------------------
# ---SHAPE left blink---
# (16, 32, 640)
# ---DATA left blink---

# %%
channelsData_rubert_left_blik[3]
# Out:
# array([[ 0.01350048,  0.09895924,  0.23428423, ..., -0.21804735,
#         -0.21223709, -0.18950457],
#        [-0.21566654, -0.27775899, -0.26127631, ..., -0.00444789,
#         -0.01552798, -0.02495369],
#        [-0.01889083, -0.01531125, -0.00408772, ..., -0.65029801,
#         -0.54085361, -0.53687679],
#        ...,
#        [-0.64355591, -0.30625457,  0.13256229, ..., -0.12470974,
#         -0.07415236, -0.10154835],
#        [-0.09656876, -0.08962827, -0.11164935, ..., -0.28221986,
#         -0.29646198, -0.3105577 ],
#        [-0.3023631 , -0.31008085, -0.32074771, ..., -0.26909607,
#         -0.17780363, -0.15797896]])

# %% [markdown]
# ### Slicing into smaller temporal windows of 2.5 seconds

# %%
import matplotlib.pyplot as plt

channel_jaw = channelsData_rubert_jaw[4]
window_jaw = channel_jaw[4]


channel_left_blink = channelsData_rubert_left_blik[4]
window_left_blink = channel_left_blink[4]
# shape (windows, samples)

plt.figure(figsize=(10,10))
plt.plot(window_jaw)
plt.show()

plt.figure(figsize=(10,10))
plt.plot(window_left_blink)
plt.show()

# %%
# Funcion para visualizar las ventanas a ver si caen correctamente en un spike:
def print_windows(allChannelsData):
  print("printing windows")
  for idChannel, channel in enumerate(allChannelsData):
    print(f"------------channel {idChannel} -------------")
    for idWindow, window in enumerate(channel):
      plt.figure(figsize=(4,4))
      plt.title(f"window {idWindow} from channel {idChannel}")
      plt.plot(window)
    

#print_windows(channelsData_jaw)
#print_windows(channelsData_left_blink)

# %% [markdown]
# ### Labeling data

# %%
# generamos un dataframe con las etiquetas donde las ventanas son mas pequeñas. (2,5 segundos)
# nos puede ayudar a que el modelo sea mejor ya que la señal está más acotada y tenemos mas ejemplos de ruido

channels_list_df_jaw = channels_to_list_df_two_and_a_half_sec_window(channelsData_rubert_jaw, 'jaw')
channels_list_df_left_blink = channels_to_list_df_two_and_a_half_sec_window(channelsData_rubert_left_blik, 'left_blink')

channel_jaw = channels_list_df_jaw[3] #pillamos el canal 4
channel_left_blink = channels_list_df_left_blink[3] #pillamos el canal 4

print(len(channels_list_df_jaw))
print(channel_jaw.shape)

print(len(channels_list_df_left_blink))
print(channel_left_blink.shape)

channel_jaw.head(32)
# Out:
# 16
# (32, 641)
# 16
# (32, 641)
#     label         0         1         2         3         4         5  \
# 0   pause -0.001498 -0.173506 -0.262872 -0.410121 -0.787764 -0.694200
# 1   pause  0.536082  0.525511  0.014600 -0.233239 -0.281869 -0.624724
# 2   pause -0.592016 -0.510948 -0.649959 -0.767562 -0.614372 -0.824543
# 3   pause  0.068203  0.297343  0.221345  0.301737  0.449888  0.173141
# 4     jaw  0.220527  0.240157  0.195508  0.226435  0.316884  0.427290
# 5   pause  0.601888  0.531498  0.468681  0.397914  0.402588  0.376769
# 6   pause -0.249724 -0.281471 -0.298519 -0.338640 -0.358999 -0.290542
# 7   pause -0.326888 -0.314767 -0.325396 -0.341832 -0.340073 -0.347869
# 8     jaw  0.105099  0.147424  0.141285  0.111527  0.093108  0.118699
# 9   pause  0.058581  0.163399  0.253293  0.293914  0.284395  0.288889
# 10  pause -0.490117 -0.376379 -0.328709 -0.229012 -0.080885 -0.350286
# 11  pause -0.335074 -0.335688 -0.387754 -0.421345 -0.501143 -0.599080
# ...

# %%
channel_left_blink.head(32)
# Out:
#          label         0         1         2         3         4         5  \
# 0        pause  0.013500  0.098959  0.234284  0.273423 -0.179843 -0.549974
# 1        pause -0.215667 -0.277759 -0.261276 -0.243795 -0.248052 -0.266368
# 2        pause -0.018891 -0.015311 -0.004088  0.015397  0.000164 -0.027041
# 3        pause -0.359826  0.002830  0.238886  0.246543  0.188481 -0.045477
# 4   left_blink  0.391684  0.692394  0.862940  0.800160  0.421202  0.072508
# 5        pause -0.043158  0.356968  0.559582  0.720541  0.780539  0.756289
# 6        pause -0.392547 -0.402193 -0.415652 -0.384426 -0.368358 -0.371422
# 7        pause -0.304717 -0.313809 -0.347230 -0.331344 -0.302978 -0.302309
# 8   left_blink -0.427663 -0.415968 -0.330078 -0.308219 -0.297124 -0.254805
# 9        pause -0.283693 -0.045830 -0.154140 -0.483869 -0.462392 -0.305732
# 10       pause -0.297356 -0.312520 -0.314444 -0.313017 -0.305700 -0.310055
# ...

# %%
# sumamos los dataframes de jaw y left_blink ambos en el canal 3, tienen que ser del mismo canal los que usemos
#df_jaw_left_blink_3 = channel_jaw.append(channel_left_blink, ignore_index=True)
#df_jaw_left_blink_3

# %% [markdown]
# ### Concatenamos varios canales

# %%
# Pasamos las etiquetas a integer: 0: pausa, 1: jaw, 2: left_blink

for channel_df_jaw in channels_list_df_jaw:
    channel_df_jaw['label'] = channel_df_jaw['label'].replace({'pause': 0, 'jaw': 1})

for channel_df_left_blink in channels_list_df_left_blink:
    channel_df_left_blink['label'] = channel_df_left_blink['label'].replace({'pause': 0, 'left_blink': 2})

#selected_channel = 0

channel_jaw_0 = channels_list_df_jaw[0] #solo el canal 0 seleccionado del df de jaw
channel_jaw_1 = channels_list_df_jaw[1]
channel_jaw_4 = channels_list_df_jaw[4] 
channel_jaw_5 = channels_list_df_jaw[5]
channel_jaw_10 = channels_list_df_jaw[10]
channel_jaw_11 = channels_list_df_jaw[11]

jaw_6_channels = pd.concat([channel_jaw_0, channel_jaw_1, channel_jaw_4, channel_jaw_5, channel_jaw_10, channel_jaw_11], axis=1, ignore_index=True)


channel_left_blink_0 = channels_list_df_left_blink[0] #solo el canal 0 seleccionado del df de blink
channel_left_blink_1 = channels_list_df_left_blink[1] 
channel_left_blink_4 = channels_list_df_left_blink[4] 
channel_left_blink_5 = channels_list_df_left_blink[5] 
channel_left_blink_10 = channels_list_df_left_blink[10] 
channel_left_blink_11 = channels_list_df_left_blink[11] 

left_blink_6_channels = pd.concat([channel_left_blink_0, channel_left_blink_1, channel_left_blink_4, channel_left_blink_5, channel_left_blink_10, channel_left_blink_11], axis=1, ignore_index=True)

df_jaw_left_blink_6_channels = jaw_6_channels.append(left_blink_6_channels, ignore_index=True)

df_jaw_left_blink_6_channels
# Out:
# (32, 641)
# (32, 641)
#     0         1         2         3         4         5         6     \
# 0      0  0.009740 -1.000000 -1.000000 -1.000000 -1.000000 -0.062951
# 1      0 -0.094009  0.534957  1.000000  0.727925  0.775086  0.043334
# 2      0 -0.330208  0.852669  0.389177 -0.247503 -0.168993 -0.568626
# 3      0 -1.000000 -0.902567 -1.000000 -1.000000 -0.776859 -1.000000
# 4      1 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -0.876114
# ..   ...       ...       ...       ...       ...       ...       ...
# 59     0 -0.996103 -1.000000 -0.982931 -0.960545 -1.000000 -0.943239
# 60     2 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 61     0  0.276507  0.741653  0.928287  0.330052  0.381116  0.604374
# 62     0 -1.000000 -1.000000 -1.000000 -1.000000 -0.953625 -0.918577
# 63     0 -0.722171 -0.678061 -0.738718 -0.713212 -0.674743 -0.744918
#
#         7         8         9     ...      3836      3837      3838      3839  \
# ...

# %%
df_jaw_left_blink_6_channels.rename(columns={0:'label'}, inplace=True)
df_jaw_left_blink_6_channels
# Out:
#     label         1         2         3         4         5         6  \
# 0       0  0.009740 -1.000000 -1.000000 -1.000000 -1.000000 -0.062951
# 1       0 -0.094009  0.534957  1.000000  0.727925  0.775086  0.043334
# 2       0 -0.330208  0.852669  0.389177 -0.247503 -0.168993 -0.568626
# 3       0 -1.000000 -0.902567 -1.000000 -1.000000 -0.776859 -1.000000
# 4       1 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -0.876114
# ..    ...       ...       ...       ...       ...       ...       ...
# 59      0 -0.996103 -1.000000 -0.982931 -0.960545 -1.000000 -0.943239
# 60      2 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 61      0  0.276507  0.741653  0.928287  0.330052  0.381116  0.604374
# 62      0 -1.000000 -1.000000 -1.000000 -1.000000 -0.953625 -0.918577
# 63      0 -0.722171 -0.678061 -0.738718 -0.713212 -0.674743 -0.744918
#
#            7         8         9  ...      3836      3837      3838      3839  \
# ...

# %% [markdown]
# ## Creamos el dataset de entrenamiento (X e Y)

# %%
# entrenamos con la suma de jaw y left_blink

Y = df_jaw_left_blink_6_channels['label']
Y
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     1
#      ..
# 59    0
# 60    2
# 61    0
# 62    0
# 63    0
# Name: label, Length: 64, dtype: int64

# %%
X = df_jaw_left_blink_6_channels.drop(['label'], axis=1)
X
# Out:
#         1         2         3         4         5         6         7     \
# 0   0.009740 -1.000000 -1.000000 -1.000000 -1.000000 -0.062951 -0.670092
# 1  -0.094009  0.534957  1.000000  0.727925  0.775086  0.043334 -0.935071
# 2  -0.330208  0.852669  0.389177 -0.247503 -0.168993 -0.568626 -0.802764
# 3  -1.000000 -0.902567 -1.000000 -1.000000 -0.776859 -1.000000 -1.000000
# 4  -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -0.876114 -0.555457
# ..       ...       ...       ...       ...       ...       ...       ...
# 59 -0.996103 -1.000000 -0.982931 -0.960545 -1.000000 -0.943239 -0.914800
# 60 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 61  0.276507  0.741653  0.928287  0.330052  0.381116  0.604374  0.458972
# 62 -1.000000 -1.000000 -1.000000 -1.000000 -0.953625 -0.918577 -0.915873
# 63 -0.722171 -0.678061 -0.738718 -0.713212 -0.674743 -0.744918 -0.751088
#
#         8         9         10    ...      3836      3837      3838      3839  \
# ...

# %%
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression

seed = 1234

X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size=0.25, shuffle=True,random_state=seed)

X_train
# Out:
#         1         2         3         4         5         6         7     \
# 36 -0.581482 -0.326000  0.150646 -0.047068 -0.200800 -0.196967 -0.380187
# 13  0.450613  0.465081  0.413521  0.502373  0.536859  0.401815  0.390822
# 25  0.433965  0.322665  0.251621  0.284222  0.223801  0.181911  0.194875
# 57  0.596150  0.523746  0.289899  0.235808 -0.163221 -0.474121 -0.223977
# 63 -0.722171 -0.678061 -0.738718 -0.713212 -0.674743 -0.744918 -0.751088
# 10 -0.869494 -0.682776 -0.556013 -0.702350 -0.525688 -0.673272 -1.000000
# 7  -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 27 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 14 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 17 -0.179407 -0.248632 -0.169396 -0.142000 -0.211761 -0.225934 -0.255659
# 46 -0.725375 -0.771313 -0.705755 -0.689637 -0.783157 -0.771403 -0.739223
# 31 -1.000000 -1.000000 -0.692014 -0.697934 -0.327478 -0.355343 -0.905701
# ...

# %%
from sklearn.model_selection import GridSearchCV

lr_params = {'C': [9.08, 10.08, 100.08, 200.08],
             'max_iter': [500, 1000,50000,100000]}

# TODO: hacer un pipeline y estandarizar los datos, al mezclarse señales distintas es mas importante ahora
# https://scikit-learn.org/stable/modules/preprocessing.html

lr_grid = GridSearchCV(estimator=LogisticRegression(random_state=seed),
                       param_grid=lr_params,
                       cv=3).fit(X_train, Y_train)

lr_grid.best_estimator_.get_params()
# Out:
# {'C': 9.08,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 500,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': 1234,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
lr_opt = LogisticRegression(C=9.08, max_iter=500, penalty='l2', random_state=seed)
stats = lr_opt.fit(X_train, Y_train)
score = lr_opt.score(X_test, Y_test)

print("--stats--")
print(stats)
print("--score--")
print(score)
# Out:
# --stats--
# LogisticRegression(C=9.08, max_iter=500, random_state=1234)
# --score--
# 0.8125

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred_lr = lr_opt.predict(X_test)

conf_matrix = confusion_matrix(Y_test, y_pred_lr, labels=[0, 1, 2])
plt.figure(figsize=[8, 6])
sns.heatmap(conf_matrix,
            annot=True,
            fmt='d')
plt.title('Confusion matrix')
plt.ylabel('True class')
plt.xlabel('Predicted class');

# %%
# guardamos el modelo

# Saving model

import pickle

filename = '6_channels_two_and_a_half_seconds_windows_rubert_jaw_and_left_blink_log_regression.pkl'
pickle.dump(lr_opt, open(filename, 'wb'))
