# %%
AEMET_key = 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJlbGVuYS50ZWphZGlsbG9zQG91dGxvb2suY29tIiwianRpIjoiY2ZmNmVlNTgtMWE1Mi00MTdhLTliOWEtZTVmNDNjNzg1MDE0IiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE1NzkzNTA2MDMsInVzZXJJZCI6ImNmZjZlZTU4LTFhNTItNDE3YS05YjlhLWU1ZjQzYzc4NTAxNCIsInJvbGUiOiIifQ.uDHOBShs7FrbbaxuGGUoSg-7tBMAK6_IVaY8Aua-pcQ'

# %%
import http.client

conn = http.client.HTTPSConnection("opendata.aemet.es")

headers = {
    'cache-control': "no-cache"
    }

conn.request("GET", "/opendata/api/valores/climatologicos/inventarioestaciones/todasestaciones/?api_key=eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJlbGVuYS50ZWphZGlsbG9zQG91dGxvb2suY29tIiwianRpIjoiY2ZmNmVlNTgtMWE1Mi00MTdhLTliOWEtZTVmNDNjNzg1MDE0IiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE1NzkzNTA2MDMsInVzZXJJZCI6ImNmZjZlZTU4LTFhNTItNDE3YS05YjlhLWU1ZjQzYzc4NTAxNCIsInJvbGUiOiIifQ.uDHOBShs7FrbbaxuGGUoSg-7tBMAK6_IVaY8Aua-pcQ", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/e016136d",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/0556af7a"
# }

# %%
import requests

url = "https://opendata.aemet.es/opendata/api/valores/climatologicos/inventarioestaciones/todasestaciones/"

querystring = {"api_key":"eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJlbGVuYS50ZWphZGlsbG9zQG91dGxvb2suY29tIiwianRpIjoiY2ZmNmVlNTgtMWE1Mi00MTdhLTliOWEtZTVmNDNjNzg1MDE0IiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE1NzkzNTA2MDMsInVzZXJJZCI6ImNmZjZlZTU4LTFhNTItNDE3YS05YjlhLWU1ZjQzYzc4NTAxNCIsInJvbGUiOiIifQ.uDHOBShs7FrbbaxuGGUoSg-7tBMAK6_IVaY8Aua-pcQ"}

headers = {
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/e016136d",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/0556af7a"
# }

# %%
import json
import io

# %%
#file = '/content/AEMET_Datos_SAGUNTO_Convencional.json'
file = '/content/Xavia2019.json'
with open(file) as json_file :
    aemet_loaded = json.load(json_file)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-40-3b98d287e25f> in <module>()
#       1 file = '/content/Xavia2019.json'
#       2 with open(file) as json_file :
# ----> 3     aemet_loaded = json.load(json_file)
#
# /usr/lib/python3.6/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     294
#     295     """
# --> 296     return loads(fp.read(),
#     297         cls=cls, object_hook=object_hook,
#     298         parse_float=parse_float, parse_int=parse_int,
#
# /usr/lib/python3.6/codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     322         # keep undecoded input until the next call
# ...

# %%
print(aemet_loaded[1])
# Out:
# {'fecha': '2019-05-02', 'indicativo': '8058X', 'nombre': 'OLIVA', 'provincia': 'VALENCIA', 'altitud': '5', 'tmed': '15,0', 'prec': '0,0', 'tmin': '11,4', 'horatmin': '23:59', 'tmax': '18,5', 'horatmax': '11:00', 'dir': '04', 'velmedia': '1,4', 'racha': '5,0', 'horaracha': '14:50'}

# %%
import pandas as pd
#df = pd.read_json (r'/content/AEMET_Datos_SAGUNTO_Convencional.json')
df = pd.read_json (r'/content/Xavia2019.json')
print(df)
# Out:
#           fecha indicativo        nombre  ... horaPresMax  presMin horaPresMin
# 0    2019-05-01      8050X  J�VEA/ X�BIA  ...          00   1012,2          16
# 1    2019-05-02      8050X  J�VEA/ X�BIA  ...          11   1012,5          04
# 2    2019-05-03      8050X  J�VEA/ X�BIA  ...          00   1009,0      Varias
# 3    2019-05-04      8050X  J�VEA/ X�BIA  ...          09   1009,8          19
# 4    2019-05-05      8050X  J�VEA/ X�BIA  ...          10   1011,0          00
# ..          ...        ...           ...  ...         ...      ...         ...
# 145  2019-09-26      8050X  J�VEA/ X�BIA  ...      Varias   1016,1          02
# 146  2019-09-27      8050X  J�VEA/ X�BIA  ...          00   1014,9          17
# 147  2019-09-28      8050X  J�VEA/ X�BIA  ...          10   1016,7      Varias
# 148  2019-09-29      8050X  J�VEA/ X�BIA  ...          00   1013,9          17
# 149  2019-09-30      8050X  J�VEA/ X�BIA  ...          10   1013,6      Varias
#
# [150 rows x 20 columns]

# %%
df_vlcpro = df[(df.provincia=='VALENCIA')]
df_alipro = df[(df.provincia=='ALICANTE')]

# %%
print(df_vlcpro)
# Out:
# Empty DataFrame
# Columns: [fecha, indicativo, nombre, provincia, altitud, tmed, prec, tmin, horatmin, tmax, horatmax, dir, velmedia, racha, horaracha, sol, presMax, horaPresMax, presMin, horaPresMin]
# Index: []

# %%
df.to_csv('/content/Xavia2019.csv', header=True, index=False)
