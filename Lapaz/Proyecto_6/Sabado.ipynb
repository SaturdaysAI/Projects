# %%
salida=False
while not salida:
    print('1) Mostrar crecimjento poblacional perros')
    print('2) Mostrar crecimjento poblacional gatos')
    print('3) Salir')
    x=input('Elija una opcion ')
    if x=='1':
        p=int(input('ingrese cantidad de mascotas perros solo si son hembras sin esterilizar '))
        cp=6*(p)
        print(cp)
    elif x=='2':
        g=int(input('ingrese cantidad de mascotas gatos solo si son hembras sin esterilizar'))
        cg=8*(g)
        print(cg)
    elif x=='3':
        print('Adios')
# Out:
# 1) Mostrar crecimjento poblacional perros
# 2) Mostrar crecimjento poblacional gatos
# 3) Salir
# Elija una opcion 1
# ingrese cantidad de mascotas perros solo si son hembras sin esterilizar 6
# 36
# 1) Mostrar crecimjento poblacional perros
# 2) Mostrar crecimjento poblacional gatos
# 3) Salir
# Elija una opcion 2
# ingrese cantidad de mascotas gatos solo si son hembras sin esterilizar9
# 72
# 1) Mostrar crecimjento poblacional perros
# 2) Mostrar crecimjento poblacional gatos
# 3) Salir
