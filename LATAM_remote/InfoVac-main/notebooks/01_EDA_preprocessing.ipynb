# %% [markdown]
# # Explorando el dataset final v. 0.1

# %%
# !pip install unidecode
# Out:
# Requirement already satisfied: unidecode in /usr/local/lib/python3.6/dist-packages (1.1.1)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
# file= 'https://raw.githubusercontent.com/christianvadillo/infovac/main/data/processed/covid_fakenews_es_utf.csv'
file= 'https://raw.githubusercontent.com/christianvadillo/infovac/main/data/processed/covid_fakenews_es_utf_21_Oct_2020_17_29.csv'

df = pd.read_csv(file)
df.head()
# Out:
#                                                  url  ...   organizacion
# 0  https://www.newtral.es/bulos-coronavirus-pcr-k...  ...        Newtral
# 1  https://colombiacheck.com/chequeos/no-ecuador-...  ...  ColombiaCheck
# 2  https://www.telemundo.com/noticias/noticias-te...  ...      Telemundo
# 3  https://factual.afp.com/la-inscripcion-en-caja...  ...    AFP Factual
# 4  https://chequeado.com/ultimas-noticias/alesso-...  ...      Chequeado
#
# [5 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7482 entries, 0 to 7481
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              7482 non-null   object
#  1   titulo           7482 non-null   object
#  2   texto            7482 non-null   object
#  3   categoria        7482 non-null   object
#  4   fecha_aparicion  7478 non-null   object
#  5   organizacion     7482 non-null   object
# dtypes: object(6)
# memory usage: 350.8+ KB

# %% [markdown]
# ## Conteo de categorías

# %%
plt.figure(figsize=(10, 5))
sns.countplot(df['categoria']);
plt.ylabel('Conteo', fontsize=12);
plt.xlabel('Categoría', fontsize=12);
plt.title('Conteo por categoría')
# Out:
# Text(0.5, 1.0, 'Conteo por categoría')

# %%
# !pip install sentiment-analysis-spanish
# Out:
# Collecting sentiment-analysis-spanish
#   Downloading https://files.pythonhosted.org/packages/25/64/28ce6db8a3d08d32105ea0dba4516049b08dd2224ab3c82e5d0e8fb30778/sentiment_analysis_spanish-0.0.24-py3-none-any.whl (15.1MB)
#      |████████████████████████████████| 15.1MB 313kB/s
# Installing collected packages: sentiment-analysis-spanish
# Successfully installed sentiment-analysis-spanish-0.0.24

# %%
from sentiment_analysis_spanish import sentiment_analysis
sentiment = sentiment_analysis.SentimentAnalysisSpanish()

df['titulo_sentiment'] = df['titulo'].apply(lambda x: sentiment.sentiment(x))
sns.displot(data=df, x='titulo_sentiment', hue='categoria', kind='kde')

# %%
df['texto_sentiment'] = df['texto'].apply(lambda x: sentiment.sentiment(x))
sns.displot(data=df, x='texto_sentiment', hue='categoria', kind='kde')

# %%
# !pip install spanish_sentiment_analysis
# Out:
# Collecting spanish_sentiment_analysis
#   Downloading https://files.pythonhosted.org/packages/9f/7b/f9864d17910f3b6c9ed7b3a7cda279a76dcf9bc92a9282536d90dc789650/spanish_sentiment_analysis-1.0.0-py3-none-any.whl (15.8MB)
#      |████████████████████████████████| 15.8MB 313kB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from spanish_sentiment_analysis) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (from spanish_sentiment_analysis) (3.2.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from spanish_sentiment_analysis) (1.18.5)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (from spanish_sentiment_analysis) (0.0)
# Collecting marisa-trie
#   Downloading https://files.pythonhosted.org/packages/20/95/d23071d0992dabcb61c948fb118a90683193befc88c23e745b050a29e7db/marisa-trie-0.7.5.tar.gz (270kB)
#      |████████████████████████████████| 276kB 44.3MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk->spanish_sentiment_analysis) (1.15.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn->spanish_sentiment_analysis) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn->spanish_sentiment_analysis) (0.17.0)
# Building wheels for collected packages: marisa-trie
#   Building wheel for marisa-trie (setup.py) ... done
#   Created wheel for marisa-trie: filename=marisa_trie-0.7.5-cp36-cp36m-linux_x86_64.whl size=861159 sha256=f112d820273ccf8b14911e1ff018fc078c4eb06575e092ba4acfc562cc299d6b
#   Stored in directory: /root/.cache/pip/wheels/45/24/79/022624fc914f0e559fe8a1141aaff1f9df810905a13fc75d57
# Successfully built marisa-trie
# Installing collected packages: marisa-trie, spanish-sentiment-analysis
# Successfully installed marisa-trie-0.7.5 spanish-sentiment-analysis-1.0.0

# %%
from classifier import *
# Out:
# Will download some functions from the nltk package if not found on the computer
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
sentiment = SentimentClassifier()

df['titulo_sentiment'] = df['titulo'].apply(lambda x: sentiment.predict(x))
sns.displot(data=df, x='titulo_sentiment', hue='categoria', kind='kde')

# %%
df['texto_sentiment'] = df['texto'].apply(lambda x: sentiment.predict(x))
sns.displot(data=df, x='texto_sentiment', hue='categoria', kind='kde')

# %%
df['texto_sentiment'].min()
# Out:
# 3.1362823392795145e-08

# %% [markdown]
# ## Conteo de caracteres

# %%
df['length_titulo'] = df['titulo'].apply(len)
sns.displot(data=df, x='length_titulo', hue='categoria', palette='viridis')
plt.title('Conteo de caracteres en los títulos');

# %%
df['length_texto'] = df['texto'].apply(len)
sns.histplot(data=df, x='length_texto', bins=1500, hue='categoria', palette='viridis')
plt.xlim(0,2000)
plt.title('Conteo de caracteres en los textos');

# %% [markdown]
# ## Conteo de palabras

# %%
df['num_palabras_titulo'] = df['titulo'].apply(lambda x: len(x.split()))

sns.displot(data=df, x='num_palabras_titulo', hue='categoria', palette='viridis')
plt.title('Conteo de palabras en los títulos');

# %%
df['num_palabras_texto'] = df['texto'].apply(len)

sns.histplot(data=df, bins=1500, x='num_palabras_texto', hue='categoria', palette='viridis')
plt.title('Conteo de palabras en los textos');
plt.xlim(0,1000);

# %% [markdown]
# ## Noticias a través del tiempo

# %%
df['fecha_aparicion'] = pd.to_datetime(df['fecha_aparicion'], utc=True)

# %%
# Ordenando las fechas
df.sort_values(by='fecha_aparicion', inplace=True, ignore_index=True)

# %%
conf = df.query("categoria == 'confiable'")
no_conf = df.query("categoria == 'no confiable'")

conf.groupby(['fecha_aparicion']).count()['categoria'].rolling('7d').sum().plot(figsize=(16,5), label='Confiable')
no_conf.groupby(['fecha_aparicion']).count()['categoria'].rolling('7d').sum().plot(figsize=(16,5), label = 'No Confiable')
plt.legend()

# %% [markdown]
# ## Palabras y stopwords más frecuentes

# %%
import nltk
import numpy as np 
import re
import unicodedata
import itertools

from collections import defaultdict, Counter
from nltk.corpus import stopwords

nltk.download('stopwords')
nltk.download('punkt')


stop_words_es = stopwords.words('spanish')  # stopwords in spanish
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# stop_words_es = stop_words_es + ['cnn', 'mas', 'si']

stop_words_es = stop_words_es + ['covid', 'coronavirus', 'lunes', 'the', 'pandemia', 
                                 'martes', 'miércoles', 'jueves', 'viernes',
                                 'domingo', 'enero', 'marzo', 'abril', 'mayo', 'junio',
                                 'julio', 'agosto', 'octubre', 'nota', 'sars', 'cov'
                                 'covid-19', 'cnn', 'mas', 'si']

# %%
# Crear vocabulario

def create_vocab(docs, rm_sw=False, rm_symb=False):
  vocab = []
  rm_stopwords = []
  for doc in docs:
    # To lowercase
    doc = doc.lower()

    if rm_symb:
      # Remove accents
      doc = unicodedata.normalize(u'NFKD', doc)\
                       .encode('ascii', 'ignore')\
                       .decode('utf8')
      # Remove numbers and punctuations
      doc = re.sub(r'[^a-zA-Z\s]', '', doc)

    # Split the text
    tokens = nltk.word_tokenize(doc)
    
    if rm_sw: 
      # To keep the track of the removed stopwords
      [rm_stopwords.append(token) for token in tokens if token in stop_words_es]
      # Remove the stopwords
      tokens = [token for token in tokens if token not in stop_words_es]
      
    vocab.append(tokens)
  # To flatt the list
  vocab = list(itertools.chain.from_iterable(vocab))
  return vocab, rm_stopwords

vocab, rm_stopwords = create_vocab(df['titulo'], rm_sw=True, rm_symb=True)
count_vocab = Counter(vocab)
count_sw = Counter(rm_stopwords)

# %%
count_vocab.most_common(100)
# Out:
# [('pandemia', 526),
#  ('trump', 394),
#  ('nuevo', 372),
#  ('video', 362),
#  ('vacuna', 351),
#  ('casos', 311),
#  ('eeuu', 292),
#  ('dice', 271),
#  ('gobierno', 228),
#  ('personas', 227),
#  ('salud', 217),
#  ('china', 214),
#  ('cuarentena', 210),
#  ('unidos', 197),
#  ('puede', 178),
#  ('muertes', 173),
#  ('presidente', 169),
#  ('oms', 168),
#  ('mundo', 164),
#  ('brasil', 156),
#  ('estan', 152),
#  ('cura', 151),
#  ('segun', 151),
#  ('imagen', 149),
#  ('pruebas', 146),
#  ('pacientes', 145),
#  ('hospital', 144),
#  ('ser', 143),
#  ('virus', 141),
#  ('millones', 141),
#  ('muestra', 139),
#  ('argentina', 132),
#  ('mexico', 131),
#  ('espana', 130),
#  ('casa', 129),
#  ('pais', 128),
#  ('sabemos', 126),
#  ('podria', 124),
#  ('dijo', 121),
#  ('colombia', 113),
#  ('medio', 112),
#  ('medicos', 111),
#  ('positivo', 110),
#  ('nueva', 108),
#  ('crisis', 108),
#  ('uso', 108),
#  ('dos', 101),
#  ('mascarillas', 101),
#  ('tras', 99),
#  ('asegura', 98),
#  ('dias', 94),
#  ('mundial', 93),
#  ('italia', 91),
#  ('agua', 90),
#  ('medico', 89),
#  ('contagio', 89),
#  ('ninos', 89),
#  ('despues', 89),
#  ('foto', 88),
#  ('pueden', 88),
#  ('estudio', 88),
#  ('anos', 87),
#  ('vacunas', 85),
#  ('medidas', 85),
#  ('asi', 84),
#  ('ahora', 83),
#  ('hacer', 83),
#  ('ciudad', 81),
#  ('paises', 81),
#  ('caso', 80),
#  ('primer', 79),
#  ('prueba', 79),
#  ('gates', 79),
#  ('falso', 78),
#  ('ayuda', 77),
#  ('expertos', 76),
#  ('g', 75),
#  ('noticias', 74),
#  ('bill', 73),
#  ('riesgo', 73),
#  ('muertos', 72),
#  ('venezuela', 72),
#  ('datos', 72),
#  ('solo', 72),
#  ('numero', 72),
#  ('tratamiento', 70),
#  ('mientras', 70),
#  ('causa', 68),
#  ('brote', 67),
#  ('dia', 67),
#  ('bolivia', 67),
#  ('ministro', 66),
#  ('dicen', 65),
#  ('menos', 65),
#  ('ecuador', 65),
#  ('enfermedad', 65),
#  ('america', 65),
#  ('confinamiento', 65),
#  ('muerte', 63),
#  ('sintomas', 63)]

# %%
count_sw.most_common(20)
# Out:
# [('de', 8392),
#  ('el', 4536),
#  ('la', 4444),
#  ('en', 3677),
#  ('que', 3274),
#  ('coronavirus', 2763),
#  ('covid', 1922),
#  ('a', 1850),
#  ('y', 1757),
#  ('por', 1690),
#  ('un', 1637),
#  ('no', 1484),
#  ('los', 1445),
#  ('del', 1419),
#  ('una', 1243),
#  ('para', 1238),
#  ('las', 1137),
#  ('con', 991),
#  ('se', 961),
#  ('es', 910)]

# %% [markdown]
# # Text Pre-processing

# %% [markdown]
# # Normalizando los textos

# %%
def normalize_document(doc, rm_sw=False, rm_symb=False):
    '''
    Cleans text including removal of whitespace, punctuation, accented characters,
    special characters and transforming to lowercase. Assumes input text is string.
    Returns clean string.
    '''
    # lower case and remove special characters\whitespaces
    if rm_symb:
      # Remove accents
      doc = unicodedata.normalize(u'NFKD', doc)\
                       .encode('ascii', 'ignore')\
                       .decode('utf8')
      # Remove numbers and punctuations
      doc = re.sub(r'[^a-zA-Z\s]', '', doc)
    # To lowercase
    doc = doc.lower()
    # Remove extra space
    doc = doc.strip()

    if rm_sw:
      # tokenize document
      tokens = nltk.word_tokenize(doc)
      # filter stopwords out of document
      filtered_tokens = [token for token in tokens if token not in stop_words_es]
      # re-create document from filtered tokens
      doc = ' '.join(filtered_tokens)
      return doc

    return doc

normalize_corpus = np.vectorize(normalize_document)

# %%
no_conf_corpus = normalize_corpus(df[df['categoria'] == 'no confiable']['texto'],
                                  rm_symb=True, rm_sw=True)
conf_corpus = normalize_corpus(df[df['categoria'] == 'confiable']['texto'],
                                  rm_symb=True, rm_sw=True)
norm_corpus = normalize_corpus(df['titulo'], rm_symb=True, rm_sw=True)

# %%
from wordcloud import WordCloud


def plot_wordcloud(corpus, title=''):
  wordcloud = WordCloud(stopwords = stop_words_es, random_state=1).generate(" ".join(corpus))
  plt.rcParams['figure.figsize'] = (15, 8)
  plt.imshow(wordcloud)
  plt.title(f'Most Common Words - {title}', fontsize = 30)
  plt.axis('off')
  plt.show()

# %%
plot_wordcloud(conf_corpus, 'Confiable')
plot_wordcloud(no_conf_corpus, 'No Confiable')

# %%
df[df['titulo'].apply(lambda x: 'bill' in x.lower())]['titulo']
# Out:
# 33      Bill Gates es el propietario de la patente del...
# 56      No hay patente del nuevo coronavirus y Bill Ga...
# 57            Bill Gates predijo el brote de coronavirus
# 63      No hay pruebas de que Bill Gates sea el propie...
# 66      La fundación de Bill Gates participó en un sim...
#                               ...
# 7114    el racismo le ha costado a ee.uu. us$ 16 billo...
# 7161    No, Bill Gates no ha confirmado que van a "imp...
# 7166    Una imagen supuestamente de la web de diario E...
# 7448    bill gates elogia tratamiento de regeneron que...
# 7450    trump firma contraoferta de estímulo económico...
# Name: titulo, Length: 92, dtype: object

# %%
df.head()
# Out:
#                                                  url  ... num_palabras_texto
# 0  https://maldita.es/malditatecnologia/2020/05/0...  ...                164
# 1  https://cnnespanol.cnn.com/2020/01/07/un-miste...  ...               6785
# 2  https://poletikard.com/el-coronavirus-en-repub...  ...                192
# 3  https://cnnespanol.cnn.com/2020/01/10/cientifi...  ...               5793
# 4  https://www.animalpolitico.com/elsabueso/falso...  ...                144
#
# [5 rows x 12 columns]

# %%
df.to_csv('covid_fakenews_es_utf_17_Nov_2020_12_48.csv', index=False)
