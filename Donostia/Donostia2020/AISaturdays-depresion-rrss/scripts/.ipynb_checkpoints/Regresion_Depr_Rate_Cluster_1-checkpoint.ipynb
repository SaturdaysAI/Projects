# %% [markdown]
# # <center>AI SATURDAYS DONOSTIA 2020<center>
#
# ## <center>Regresión Indicador "DeprRate" (Índice de Depresión) - Cluster 1</center>
#
# ## <center>Proyecto Práctico Equipo FACEMOOD</center><img src="attachment:image.png" width="400">

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from regresion_functions import *
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Conjunto de Datos con 3 Clusters

# %%
df = pd.read_csv('../processed-data/cluster3_socialmedia_data.csv', index_col=0)
df.head()
# Out:
#                   PSMU       News       ASMU    Fatigue    LowMood  \
# Participant
# 115091       32.883117  15.012987  16.792208  45.155844  20.454545
# 131183       45.203390  11.593220  28.254237  36.288136   3.474576
# 438907       44.595745  34.645833  27.040816  51.040816  26.285714
# 515070       25.711538  38.576923  37.826923  34.865385  12.692308
# 572172       36.852273  45.250000  40.545455  18.272727  10.738636
#
#              Loneliness  Concentrat  LossOfInt   Inferior   Hopeless  \
# Participant
# 115091        23.285714   37.272727  47.675325  17.831169  21.389610
# 131183         0.389831   19.508475  14.508475   0.254237   0.406780
# 438907        21.833333   35.729167  50.979592  23.395833  14.591837
# 515070        14.076923   32.903846  16.038462  11.403846  10.500000
# 572172         9.375000   14.352273  25.761364  38.056818  17.431818
#
#                 Stress  Sintomas_Cluster3
# Participant
# 115091       37.441558                  1
# 131183       16.898305                  0
# 438907       25.000000                  1
# 515070       17.365385                  0
# 572172       20.511364                  0

# %% [markdown]
# ### Creación Índice de Depresión

# %%
df["DeprRate"]=(df["LowMood"]+df["LossOfInt"]+df["Hopeless"])/3
df.head()
# Out:
#                   PSMU       News       ASMU    Fatigue    LowMood  \
# Participant
# 115091       32.883117  15.012987  16.792208  45.155844  20.454545
# 131183       45.203390  11.593220  28.254237  36.288136   3.474576
# 438907       44.595745  34.645833  27.040816  51.040816  26.285714
# 515070       25.711538  38.576923  37.826923  34.865385  12.692308
# 572172       36.852273  45.250000  40.545455  18.272727  10.738636
#
#              Loneliness  Concentrat  LossOfInt   Inferior   Hopeless  \
# Participant
# 115091        23.285714   37.272727  47.675325  17.831169  21.389610
# 131183         0.389831   19.508475  14.508475   0.254237   0.406780
# 438907        21.833333   35.729167  50.979592  23.395833  14.591837
# 515070        14.076923   32.903846  16.038462  11.403846  10.500000
# 572172         9.375000   14.352273  25.761364  38.056818  17.431818
#
#                 Stress  Sintomas_Cluster3   DeprRate
# Participant
# 115091       37.441558                  1  29.839827
# 131183       16.898305                  0   6.129944
# 438907       25.000000                  1  30.619048
# 515070       17.365385                  0  13.076923
# 572172       20.511364                  0  17.977273

# %% [markdown]
# ### Nuevo Conjunto de Datos

# %%
df2 = df[["DeprRate","Fatigue", "Loneliness", "Concentrat", "Inferior", "Stress", "PSMU", "News", "ASMU", "Sintomas_Cluster3"]]
print(df2.head())
print("No. Filas/Columnas del Conjunto de Datos: {}".format(df2.shape))
# Out:
#               DeprRate    Fatigue  Loneliness  Concentrat   Inferior  \
# Participant
# 115091       29.839827  45.155844   23.285714   37.272727  17.831169
# 131183        6.129944  36.288136    0.389831   19.508475   0.254237
# 438907       30.619048  51.040816   21.833333   35.729167  23.395833
# 515070       13.076923  34.865385   14.076923   32.903846  11.403846
# 572172       17.977273  18.272727    9.375000   14.352273  38.056818
#
#                 Stress       PSMU       News       ASMU  Sintomas_Cluster3
# Participant
# 115091       37.441558  32.883117  15.012987  16.792208                  1
# 131183       16.898305  45.203390  11.593220  28.254237                  0
# 438907       25.000000  44.595745  34.645833  27.040816                  1
# 515070       17.365385  25.711538  38.576923  37.826923                  0
# 572172       20.511364  36.852273  45.250000  40.545455                  0
# No. Filas/Columnas del Conjunto de Datos: (125, 10)

# %% [markdown]
# ### Datos Cluster 1

# %%
df3=df2[df2["Sintomas_Cluster3"]==1]
df3= df3[["DeprRate","Fatigue", "Loneliness", "Concentrat", "Inferior", "Stress", "PSMU", "News", "ASMU"]]
print(df3.head())
print("No. Filas/Columnas del Conjunto de Datos: {}".format(df3.shape))
# Out:
#               DeprRate    Fatigue  Loneliness  Concentrat   Inferior  \
# Participant
# 115091       29.839827  45.155844   23.285714   37.272727  17.831169
# 438907       30.619048  51.040816   21.833333   35.729167  23.395833
# 680605       19.715789  60.894737    3.663158   46.852632   3.000000
# 1500743      23.871486  40.156627    9.228916   45.072289  14.855422
# 1875048      29.424840  45.859375   24.312500   33.203125  13.765625
#
#                 Stress       PSMU       News       ASMU
# Participant
# 115091       37.441558  32.883117  15.012987  16.792208
# 438907       25.000000  44.595745  34.645833  27.040816
# 680605       40.063158  34.547368  14.631579   1.463158
# 1500743      32.554217  32.590361  16.566265  25.939759
# 1875048      33.468750  24.953125   5.843750  21.738462
# No. Filas/Columnas del Conjunto de Datos: (44, 9)

# %% [markdown]
# ### Estadísticas descriptivas de las medias por participante del Cluster 1

# %%
df3.describe()
# Out:
#         DeprRate    Fatigue  Loneliness  Concentrat   Inferior     Stress  \
# count  44.000000  44.000000   44.000000   44.000000  44.000000  44.000000
# mean   28.404460  50.521560   22.846137   40.236774  19.231795  35.817086
# std     7.177234  12.466464    9.969584   10.384211  10.700234   9.783799
# min    15.672565  26.907407    3.663158   25.296296   0.019608  16.755814
# 25%    23.864855  41.682495   17.595238   32.507143  13.275786  30.492831
# 50%    27.002572  49.808840   22.504956   39.516372  19.319166  34.390741
# 75%    30.555556  57.380229   27.260168   46.035033  23.678504  40.341019
# max    51.952941  78.378947   53.788235   70.562500  52.658824  61.482353
#
#             PSMU       News       ASMU
# count  44.000000  44.000000  44.000000
# mean   33.850722  24.046184  25.449406
# std    12.804289  13.404588  14.314653
# min    11.229167   0.308642   1.039216
# 25%    26.915616  13.856618  16.576299
# 50%    32.467908  24.202008  24.991765
# 75%    40.712885  33.532536  30.740316
# max    75.413043  49.215686  58.786885

# %% [markdown]
# ### Diagrama de Matriz para las Medias de las 9 Variables

# %%
printMatrixDiagram(df3)   # Función definida en "regresion_functions"

# %% [markdown]
# ### Correlaciones de Pearson para las Medias de las 9 Variables

# %%
printPearsonCorrelations(df3)   # Función definida en "regresion_functions"

# %% [markdown]
# ### Se observan correlaciones más significativas entre las siguientes variables:
#
# DeprRate vs Loneliness
#
# DeprRate vs Inferior
#
# Loneliness vs Inferior
#
#
# No se observa "multicolinealidad"

# %% [markdown]
# ### Regresión Lineal para las Medias: y = DeprRate, X = Demás Variables

# %%
label = df3.DeprRate

df3.drop('DeprRate', axis=1, inplace=True)

# %% [markdown]
# ### Proceso de eliminación de variables X que no contribuyen significativamente para explicar y

# %%
resultsummary = pd.DataFrame(data={'iteration': [], 'intercept': [], 'RMSE_Training': [], 'RMSE_Testing': [],
                                   'R2_Training': [],'R2_Testing': [],'p_value_max':[],'removed_var':[]})

data_list_medias = calculateRegression(df3, label, resultsummary, alpha=0.15)   # Función definida en "regresion_functions"
# Out:
#    iteration  intercept  RMSE_Training  RMSE_Testing  R2_Training  R2_Testing  \
# 0        0.0      2.680          3.461         3.232        0.803      -0.225
# 1        1.0      2.228          3.468         3.121        0.802      -0.143
# 2        2.0      2.573          3.473         3.320        0.802      -0.293
# 3        3.0      1.842          3.510         3.229        0.798      -0.223
#
#    p_value_max removed_var
# 0        0.911        PSMU
# 1        0.633     Fatigue
# 2        0.539        ASMU
# 3        0.115           -
#
# Modelo Final
# ['Loneliness', 'Concentrat', 'Inferior', 'Stress', 'News']
# [0.33411428 0.16053377 0.19752373 0.18577859 0.07565841] 1.8420832771152718
# RMSE of Linear Regression Model with Training Data: 3.51
# RMSE of Linear Regression Model with Testing Data: 3.23
# R2 Coefficient for Linear Regression Model with Training Data: 0.798
# R2 Coefficient for Linear Regression Model with Testing Data: -0.223

# %% [markdown]
# ### Análisis de Residuos Modelo Final

# %%
fitt = data_list_medias[5]
standardized_residuals = data_list_medias[4]

residualAnalysis(fitt, standardized_residuals)   # Función definida en "regresion_functions"
# Out:
# Estadística prueba normalidad Kolmogorov-Smirnov=0.107, pvalue=0.815
#
# Probablemente Normal

# %% [markdown]
# ## Conclusión Final Modelo Ajustado (Cluster 1; y = DeprRate)
# #####
# ### El coeficiente de determinación (R2) del modelo ajustado para las "medias" del Cluster 1 es alto (79,8%).
# ### El Análisis de Residuos ha sido considerado satisfactorio, teniendo en cuenta la escasez de datos.
# ### En principio, se valida el modelo bajo un punto de vista estadístico.
# #### Nota: Debido a la escasez de los datos reservados para el testeo (total de 9 participantes), no tendremos en cuenta el "R2 Testing Data".
# #####
# ### DeprRate = 1,84 + 0,33 Loneliness + 0,20 Inferior + 0,19 Stress + 0,16 Concentrat  + 0,08 News
